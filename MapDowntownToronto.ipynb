# %% [markdown]
# ## PYTHON CODE -> Segmenting and Clustering Neighborhoods in Toronto

# %% [markdown]
# ### Installing & Importing Libraries

# %%
#IMPORTING NUMPY
import numpy as np 
#IMPORTING PANDAS
import pandas as pd
#IMPORTING JSON
import json
#INSTALLING & IMPORTING GEOPY
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
#IMPORTING REQUESTS
import requests 
from pandas.io.json import json_normalize
#IMPORTING MATPLOTLIB
import matplotlib.cm as cm
import matplotlib.colors as colors
#IMPORTING KMEANS
from sklearn.cluster import KMeans
#INSTALLING & IMPORING FOLIUM
# !conda install -c conda-forge folium=0.5.0 --yes
import folium
#IMPORTING BEAUTIFULSOUP
from bs4 import BeautifulSoup
#IMPORTING LXML
import lxml
from selenium import webdriver
print('Libraries installed & imported.')
# Out:
# Libraries installed & imported.

# %% [markdown]
# ### Importing Toronto Table

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
table = pd.read_html(url)
data = table[0]
data.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %% [markdown]
# ### Data Cleaning

# %%
#Removing 'Not assigned' Values
data = data[data.Borough!='Not assigned']
number_of_rows = data.shape[0]
#Replacing unknown neighbourhood values with borough name
for i in range(0,number_of_rows):
    if data.iloc[i][2] == 'Not assigned':
        data.iloc[i][2] = data.iloc[i][1]
#Grouping similar postcodes & boroughs into single row
df = data.groupby(['Postcode','Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df.rename(columns = {'Postcode':'Postal Code'},inplace= True)
df.head()
# Out:
#   Postal Code      Borough                           Neighbourhood
# 0         M1B  Scarborough                          Rouge, Malvern
# 1         M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill
# 3         M1G  Scarborough                                  Woburn
# 4         M1H  Scarborough                               Cedarbrae

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ### Loading Co-ordinates CSV

# %%
coordinates = pd.read_csv('Geospatial_Coordinates.csv')
coordinates.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Mergining Co-ordinates with Clean Data

# %%
toronto = df.merge(coordinates,how='right')
toronto.head()
# Out:
#   Postal Code      Borough                           Neighbourhood   Latitude  \
# 0         M1B  Scarborough                          Rouge, Malvern  43.806686
# 1         M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2         M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3         M1G  Scarborough                                  Woburn  43.770992
# 4         M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ## CREATING A MAP

# %% [markdown]
# ### Finding Co-ordinates of Toronto

# %%
address = 'Toronto, Ontario'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %% [markdown]
# ### Creating a map using Folium

# %%
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=11)
#Adding Markers
for lat, lng, borough, neighbourhood in zip(toronto['Latitude'],toronto['Longitude'],toronto['Borough'],toronto['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.5,
        parse_html=False).add_to(map_toronto)  
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Listing Boroughs

# %%
toronto['Borough'].value_counts()
# Out:
# North York          24
# Downtown Toronto    18
# Scarborough         17
# Etobicoke           12
# Central Toronto      9
# West Toronto         6
# York                 5
# East Toronto         5
# East York            5
# Queen's Park         1
# Mississauga          1
# Name: Borough, dtype: int64

# %% [markdown]
# ### Let us choose Downtown Toronto

# %%
DT = toronto[toronto['Borough'] == 'Downtown Toronto'].reset_index(drop=True)
DT.head()
# Out:
#   Postal Code           Borough                Neighbourhood   Latitude  \
# 0         M4W  Downtown Toronto                     Rosedale  43.679563
# 1         M4X  Downtown Toronto  Cabbagetown, St. James Town  43.667967
# 2         M4Y  Downtown Toronto         Church and Wellesley  43.665860
# 3         M5A  Downtown Toronto    Harbourfront, Regent Park  43.654260
# 4         M5B  Downtown Toronto     Ryerson, Garden District  43.657162
#
#    Longitude
# 0 -79.377529
# 1 -79.367675
# 2 -79.383160
# 3 -79.360636
# 4 -79.378937

# %% [markdown]
# ### Location Downtown Toronto

# %%
address = 'Downtown Toronto, ON'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.655115, -79.380219.

# %%
map_DT = folium.Map(location=[latitude, longitude], zoom_start=13)
for lat, lng, label in zip(DT['Latitude'],DT['Longitude'],DT['Neighbourhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='green',
        fill=True,
        fill_color='green',
        fill_opacity=0.5,
        parse_html=False).add_to(map_DT)  
    
map_DT
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Foursquare API Details

# %%
CLIENT_ID = 'SPJ5ZZH2JCBKLK3Y5HF51JBNPK5GGGPI2J43MDND3Z3MFD2L' # your Foursquare ID
CLIENT_SECRET = 'Y1J35FIYYFC1LUW3ATM0TVBTB1E3TVY4ALG2F2FZXSXYNCFB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# ### Exploring Neighbourhoods in Downtown Toronto

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500,LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        #API ->Request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        #Getting the values
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])
    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    return(nearby_venues)

# %%
DT_venues = getNearbyVenues(names=DT['Neighbourhood'],
                                   latitudes=DT['Latitude'],
                                   longitudes=DT['Longitude']
                                  )
# Out:
# Rosedale
# Cabbagetown, St. James Town
# Church and Wellesley
# Harbourfront, Regent Park
# Ryerson, Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide, King, Richmond
# Harbourfront East, Toronto Islands, Union Station
# Design Exchange, Toronto Dominion Centre
# Commerce Court, Victoria Hotel
# Harbord, University of Toronto
# Chinatown, Grange Park, Kensington Market
# CN Tower, Bathurst Quay, Island airport, Harbourfront West, King and Spadina, Railway Lands, South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place, Underground city
# Christie

# %%
print(DT_venues.shape)
DT_venues.head()
# Out:
# (1301, 7)
#   Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0      Rosedale               43.679563               -79.377529
# 1      Rosedale               43.679563               -79.377529
# 2      Rosedale               43.679563               -79.377529
# 3      Rosedale               43.679563               -79.377529
# 4      Rosedale               43.679563               -79.377529
#
#                   Venue  Venue Latitude  Venue Longitude Venue Category
# 0       Mooredale House       43.678631       -79.380091       Building
# 1         Rosedale Park       43.682328       -79.378934     Playground
# 2          Whitney Park       43.682036       -79.373788           Park
# 3  Alex Murray Parkette       43.678300       -79.382773           Park
# 4        Milkman's Lane       43.676352       -79.373842          Trail

# %%
DT_onehot = pd.get_dummies(DT_venues[['Venue Category']], prefix="", prefix_sep="")
DT_onehot['Neighbourhood'] = DT_venues['Neighbourhood'] 
fixed_columns = [DT_onehot.columns[-1]] + list(DT_onehot.columns[:-1])
DT_onehot = DT_onehot[fixed_columns]
DT_grouped = DT_onehot.groupby('Neighbourhood').mean().reset_index()
DT_grouped
# Out:
#                                         Neighbourhood  Afghan Restaurant  \
# 0                            Adelaide, King, Richmond            0.00000
# 1                                         Berczy Park            0.00000
# 2   CN Tower, Bathurst Quay, Island airport, Harbo...            0.00000
# 3                         Cabbagetown, St. James Town            0.00000
# 4                                  Central Bay Street            0.00000
# 5           Chinatown, Grange Park, Kensington Market            0.00000
# 6                                            Christie            0.00000
# 7                                Church and Wellesley            0.01087
# 8                      Commerce Court, Victoria Hotel            0.00000
# 9            Design Exchange, Toronto Dominion Centre            0.00000
# 10             First Canadian Place, Underground city            0.00000
# 11                     Harbord, University of Toronto            0.00000
# ...

# %%
num_top_venues = 5
for hood in DT_grouped['Neighbourhood']:
    print(hood.upper())
    temp = DT_grouped[DT_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ADELAIDE, KING, RICHMOND
#             venue  freq
# 0     Coffee Shop  0.08
# 1            Café  0.05
# 2      Steakhouse  0.04
# 3             Bar  0.04
# 4  Cosmetics Shop  0.03
#
#
# BERCZY PARK
#                 venue  freq
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2      Farmers Market  0.04
# 3  Italian Restaurant  0.04
# 4                Café  0.04
#
#
# CN TOWER, BATHURST QUAY, ISLAND AIRPORT, HARBOURFRONT WEST, KING AND SPADINA, RAILWAY LANDS, SOUTH NIAGARA
#               venue  freq
# 0    Airport Lounge  0.13
# 1   Airport Service  0.13
# 2  Airport Terminal  0.13
# 3             Plane  0.07
# 4   Harbor / Marina  0.07
#
#
# CABBAGETOWN, ST. JAMES TOWN
#                 venue  freq
# 0         Coffee Shop  0.07
# 1            Pharmacy  0.04
# 2  Italian Restaurant  0.04
# 3         Pizza Place  0.04
# 4                Park  0.04
#
#
# CENTRAL BAY STREET
#                        venue  freq
# 0                Coffee Shop  0.14
# ...

# %% [markdown]
# ### K-Means Clustering

# %%
k = 5
DT_grouped_clustering = DT_grouped.drop('Neighbourhood', 1)
#Clustering
kmeans = KMeans(n_clusters=k, random_state=0).fit(DT_grouped_clustering)
kmeans.labels_[0:10]
# Out:
# array([0, 0, 3, 0, 0, 2, 4, 0, 0, 0])

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10
indicators = ['st', 'nd', 'rd']
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = DT_grouped['Neighbourhood']

for ind in np.arange(DT_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(DT_grouped.iloc[ind, :], num_top_venues)
neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                           Adelaide, King, Richmond           Coffee Shop
# 1                                        Berczy Park           Coffee Shop
# 2  CN Tower, Bathurst Quay, Island airport, Harbo...        Airport Lounge
# 3                        Cabbagetown, St. James Town           Coffee Shop
# 4                                 Central Bay Street           Coffee Shop
#
#   2nd Most Common Venue      3rd Most Common Venue 4th Most Common Venue  \
# 0                  Café                 Steakhouse                   Bar
# 1          Cocktail Bar         Seafood Restaurant                Bakery
# 2       Airport Service           Airport Terminal       Harbor / Marina
# 3    Italian Restaurant                     Bakery                  Park
# 4                  Café  Middle Eastern Restaurant    Italian Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# ...

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
DT_merged = DT
DT_merged = DT_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

DT_merged.head() # check the last columns!
# Out:
#   Postal Code           Borough                Neighbourhood   Latitude  \
# 0         M4W  Downtown Toronto                     Rosedale  43.679563
# 1         M4X  Downtown Toronto  Cabbagetown, St. James Town  43.667967
# 2         M4Y  Downtown Toronto         Church and Wellesley  43.665860
# 3         M5A  Downtown Toronto    Harbourfront, Regent Park  43.654260
# 4         M5B  Downtown Toronto     Ryerson, Garden District  43.657162
#
#    Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0 -79.377529               1                  Park            Playground
# 1 -79.367675               0           Coffee Shop    Italian Restaurant
# 2 -79.383160               0           Coffee Shop               Gay Bar
# 3 -79.360636               0           Coffee Shop                   Pub
# 4 -79.378937               0           Coffee Shop        Clothing Store
#
#   3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# ...

# %% [markdown]
# ### Visualizing Clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]
#Adding Markers
markers_colors = []
for lat, lon, poi, cluster in zip(DT_merged['Latitude'],DT_merged['Longitude'],DT_merged['Neighbourhood'],DT_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Examining Clusters

# %% [markdown]
# ### Cluster 0

# %%
DT_merged.loc[DT_merged['Cluster Labels'] == 0, DT_merged.columns[[1] + list(range(5, DT_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 1   Downtown Toronto               0           Coffee Shop
# 2   Downtown Toronto               0           Coffee Shop
# 3   Downtown Toronto               0           Coffee Shop
# 4   Downtown Toronto               0           Coffee Shop
# 5   Downtown Toronto               0           Coffee Shop
# 6   Downtown Toronto               0           Coffee Shop
# 7   Downtown Toronto               0           Coffee Shop
# 8   Downtown Toronto               0           Coffee Shop
# 9   Downtown Toronto               0           Coffee Shop
# 10  Downtown Toronto               0           Coffee Shop
# 11  Downtown Toronto               0           Coffee Shop
# 15  Downtown Toronto               0           Coffee Shop
# 16  Downtown Toronto               0           Coffee Shop
#
#    2nd Most Common Venue      3rd Most Common Venue  \
# 1     Italian Restaurant                     Bakery
# ...

# %% [markdown]
# ### Cluster 1

# %%
DT_merged.loc[DT_merged['Cluster Labels'] == 1, DT_merged.columns[[1] + list(range(5, DT_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 0  Downtown Toronto               1                  Park
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0            Playground                 Trail              Building
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0           Yoga Studio    Dim Sum Restaurant  Ethiopian Restaurant
#
#   8th Most Common Venue        9th Most Common Venue 10th Most Common Venue
# 0     Electronics Store  Eastern European Restaurant    Dumpling Restaurant

# %% [markdown]
# ### Cluster 2

# %%
DT_merged.loc[DT_merged['Cluster Labels'] == 2, DT_merged.columns[[1] + list(range(5, DT_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 12  Downtown Toronto               2                  Café
# 13  Downtown Toronto               2                  Café
#
#             2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12                        Theater                Bakery             Bookstore
# 13  Vegetarian / Vegan Restaurant                   Bar    Chinese Restaurant
#
#    5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 12        Sandwich Place             Restaurant                   Bar
# 13   Dumpling Restaurant  Vietnamese Restaurant                Bakery
#
#    8th Most Common Venue 9th Most Common Venue   10th Most Common Venue
# 12   Japanese Restaurant          Noodle House  Comfort Food Restaurant
# 13    Mexican Restaurant           Coffee Shop              Gaming Cafe

# %% [markdown]
# ### Cluster 3

# %%
DT_merged.loc[DT_merged['Cluster Labels'] == 3, DT_merged.columns[[1] + list(range(5, DT_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 14  Downtown Toronto               3        Airport Lounge
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 14       Airport Service      Airport Terminal       Harbor / Marina
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 14                   Bar                 Plane           Coffee Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 14      Sculpture Garden              Boutique          Boat or Ferry

# %% [markdown]
# ### Cluster 4

# %%
DT_merged.loc[DT_merged['Cluster Labels'] == 4, DT_merged.columns[[1] + list(range(5, DT_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 17  Downtown Toronto               4         Grocery Store
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 17                  Café                  Park             Nightclub
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 17                 Diner            Restaurant    Italian Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 17            Baby Store    Athletics & Sports      Convenience Store
