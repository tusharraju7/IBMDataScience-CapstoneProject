# %% [markdown]
# # Introduction

# %% [markdown]
#    **Chennai** also known as **Madras** is the capital of the **Indian state of Tamil Nadu**. Chennai is among the **most-visited Indian cities by foreign tourists**. Tourism-guide publisher **Lonely Planet** named Chennai as **one of the top ten cities in the world to visit in 2015**. Chennai was ranked the **43rd-most visited city in the world** for the year 2015. The **Quality of Living Survey** rated Chennai as the **safest city in India**. Chennai attracts 45 percent of health tourists visiting India, and 30 to 40 percent of domestic health tourists. **National Geographic** mentioned Chennai as the **only South Asian city** to feature in its 2015 **"Top 10 food cities"** list. Chennai was also named the **ninth-best cosmopolitan city in the world** by Lonely Planet. In October 2017, Chennai was added to the **UNESCO Creative Cities Network (UCCN) list for its rich musical tradition**.

# %% [markdown]
# ### Business Problem

# %% [markdown]
# In recent days, the **tourism of this beautiful city has decreased**. Tourism not only adds to the country's economy but is a core part of income. How do we increase tourism and bring back the popularity of the city? In-order to achieve this, we need the **tourists to have a good experience and moreover a personalized one**. We can achieve this with the help of data science.

# %% [markdown]
# ### Target Audience

# %% [markdown]
# With all this tourist attraction taken into account, a system that can find a place suitable for the tourist to visit during their stay will be helpful. Our goal is to **identify places based on their rating & pricing** and make it visible to the tourists in-order for them **to choose a place to visit based on their budget and based on the venue's rating**.This will eventually increase the tourism level of Chennai.
#
#    We will be clustering the places to visit based on the data we recieve from the **Foursquare API** & **Zomato API**.

# %% [markdown]
# # Data

# %% [markdown]
# Our objective is to search within a **5km radius of Chennai** located at the **Latitude : 13.0827° N** & **Longitude : 80.2707° E**. Using the FoursquareAPI & ZomatoAPI the data mentioned below is retrieved. Based on the Venue Name, Latitude & Longitude obtained from the FoursquareAPI we request for data from the ZomatoAPI. We have collected a total of **120 Venues within a 5km radius** of the geographical co-ordinates of Chennai. Since we are using two datasets each from different API, there maybe some noise. In-order to clean this data, we are eliminating venues with latitude & longitude values more than 0.0004. On cleaning this data we are left with **75venues** to obtain a working model.

# %% [markdown]
# The following data has been collected from the **FoursquareAPI** :
# * Venue Name
# * Category
# * Latitude
# * Longitude
#
# The following data has been collected from the **ZomatoAPI** :
# * Average Price for Two People
# * Price Range
# * Rating
# * Address

# %% [markdown]
# ### Importing Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
from pandas.io.json import json_normalize
import requests
import folium

# %% [markdown]
# First we have to locate Chennai on the map, we are doing this by **providing the Latitude & Longitude co-ordinates for Chennai**.

# %%
chennai_latitude = 13.0827
chennai_longitude = 80.2707
print('The Geo Co-ordinates of Chennai, India are \nLatitude : {}\nLongitude : {}'.format(chennai_latitude,chennai_longitude))
# Out:
# The Geo Co-ordinates of Chennai, India are
# Latitude : 13.0827
# Longitude : 80.2707

# %% [markdown]
# Now we can pinpoint the location of chennai onto the map using the latitude & longitude co-ordinates with the help of the **folium library.**

# %%
chennai = folium.Map(location = [chennai_latitude,chennai_longitude], zoom_start = 15)
folium.Marker([chennai_latitude,chennai_longitude]).add_to(chennai)
chennai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# In-order to access the FoursquareAPI, we need to specify the developer's **Client ID, Client Secret & API Version.**

# %%
client_id = 'SPJ5ZZH2JCBKLK3Y5HF51JBNPK5GGGPI2J43MDND3Z3MFD2L'
client_secret = 'Y1J35FIYYFC1LUW3ATM0TVBTB1E3TVY4ALG2F2FZXSXYNCFB'
version = '20180605'

# %% [markdown]
# Now we define a function called **get_category_type to retrieve categories of each venue**.

# %%
def get_category_type(row):
    categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %% [markdown]
# Now with the help of a while loop, we will be requesting data from the FoursquareAPI. We must **specify the Client ID, Client Secret, API Version, Chennai-Latitude, Chennai-Longitude, Search Radius (5km) & the limit**.

# %%
fs_venues = pd.DataFrame(columns = ['name', 'categories', 'lat', 'lng'])
radius = 5000 
limit = 100
offset = 0
total_venues = 0
while (True):
    url = ('https://api.foursquare.com/v2/venues/explore?client_id={}'
           '&client_secret={}&v={}&ll={},{}&radius={}&limit={}&offset={}').format(client_id, 
                                                                        client_secret, 
                                                                        version, 
                                                                        chennai_latitude, 
                                                                        chennai_longitude, 
                                                                        radius,
                                                                        limit,
                                                                        offset)
    result = requests.get(url).json()
    venues_fetched = len(result['response']['groups'][0]['items'])
    total_venues = total_venues + venues_fetched
    venues = result['response']['groups'][0]['items']
    venues = json_normalize(venues)

    # Filter the columns
    filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
    venues = venues.loc[:, filtered_columns]
    
    # Filter the category for each row
    venues['venue.categories'] = venues.apply(get_category_type, axis = 1)
    
    # Clean all column names
    venues.columns = [col.split(".")[-1] for col in venues.columns]
    fs_venues = pd.concat([fs_venues, venues], axis = 0, sort = False)
    
    if (venues_fetched < 100):
        break
    else:
        offset = offset + 100

fs_venues = fs_venues.reset_index(drop = True)
print("Total Number of Venues Retrieved : {}".format(total_venues))
# Out:
# Total Number of Venues Retrieved : 101

# %% [markdown]
# Now with the **venues retrieved and the data for each venue stored in the dataframe fs_venues**, we can now visualize the locations of each venue on the map with the help of the folium library.

# %%
fs_chennai_map = folium.Map(location = [chennai_latitude, chennai_longitude], zoom_start = 13)
for name, lat, lng in zip(fs_venues['name'], fs_venues['lat'], fs_venues['lng']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'blue',
        fill = True,
        fill_color = 'blue',
        fill_opacity = 0.5,
        parse_html = False).add_to(fs_chennai_map)  
fs_chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now in-order to get data about the **rating & pricing of each venue we have to use the ZomatoAPI**. We **must specify our unique user-key**. With the help of a for loop **we send a request to the ZomatoAPI with the details of latitude, longitude, ... for each venue & retrieve the rating, pricing, address, ... for the respective venue** from the ZomatoAPI. The venues are stored in a new dataframe **z_venues.**

# %%
headers = {'user-key': 'f7cd1d6c3bc13dc7e6a88c6ad92d7f49'}
venues_information = []

for index, row in fs_venues.iterrows():
    print("Retrieving data for venue : {}".format(index + 1))
    venue = []
    url = ('https://developers.zomato.com/api/v2.1/search?q={}' + 
          '&start=0&count=1&lat={}&lon={}&sort=real_distance').format(row['name'], row['lat'], row['lng'])
    result = requests.get(url, headers = headers).json()
    if (len(result['restaurants']) > 0):
        venue.append(result['restaurants'][0]['restaurant']['name'])
        venue.append(result['restaurants'][0]['restaurant']['location']['latitude'])
        venue.append(result['restaurants'][0]['restaurant']['location']['longitude'])
        venue.append(result['restaurants'][0]['restaurant']['average_cost_for_two'])
        venue.append(result['restaurants'][0]['restaurant']['price_range'])
        venue.append(result['restaurants'][0]['restaurant']['user_rating']['aggregate_rating'])
        venue.append(result['restaurants'][0]['restaurant']['location']['address'])
        venues_information.append(venue)
    else:
        venues_information.append(np.zeros(6))
    
z_venues = pd.DataFrame(venues_information, 
                                  columns = ['venue', 'latitude', 
                                             'longitude', 'price_for_two', 
                                             'price_range', 'rating', 'address'])
# Out:
# Retrieving data for venue : 1
# Retrieving data for venue : 2
# Retrieving data for venue : 3
# Retrieving data for venue : 4
# Retrieving data for venue : 5
# Retrieving data for venue : 6
# Retrieving data for venue : 7
# Retrieving data for venue : 8
# Retrieving data for venue : 9
# Retrieving data for venue : 10
# Retrieving data for venue : 11
# Retrieving data for venue : 12
# Retrieving data for venue : 13
# Retrieving data for venue : 14
# Retrieving data for venue : 15
# Retrieving data for venue : 16
# Retrieving data for venue : 17
# Retrieving data for venue : 18
# Retrieving data for venue : 19
# Retrieving data for venue : 20
# Retrieving data for venue : 21
# Retrieving data for venue : 22
# Retrieving data for venue : 23
# Retrieving data for venue : 24
# Retrieving data for venue : 25
# Retrieving data for venue : 26
# Retrieving data for venue : 27
# Retrieving data for venue : 28
# Retrieving data for venue : 29
# Retrieving data for venue : 30
# Retrieving data for venue : 31
# Retrieving data for venue : 32
# Retrieving data for venue : 33
# Retrieving data for venue : 34
# Retrieving data for venue : 35
# Retrieving data for venue : 36
# Retrieving data for venue : 37
# Retrieving data for venue : 38
# Retrieving data for venue : 39
# Retrieving data for venue : 40
# Retrieving data for venue : 41
# Retrieving data for venue : 42
# Retrieving data for venue : 43
# Retrieving data for venue : 44
# Retrieving data for venue : 45
# Retrieving data for venue : 46
# Retrieving data for venue : 47
# Retrieving data for venue : 48
# Retrieving data for venue : 49
# Retrieving data for venue : 50
# Retrieving data for venue : 51
# Retrieving data for venue : 52
# Retrieving data for venue : 53
# Retrieving data for venue : 54
# Retrieving data for venue : 55
# Retrieving data for venue : 56
# Retrieving data for venue : 57
# Retrieving data for venue : 58
# Retrieving data for venue : 59
# Retrieving data for venue : 60
# Retrieving data for venue : 61
# Retrieving data for venue : 62
# Retrieving data for venue : 63
# Retrieving data for venue : 64
# Retrieving data for venue : 65
# Retrieving data for venue : 66
# Retrieving data for venue : 67
# Retrieving data for venue : 68
# Retrieving data for venue : 69
# Retrieving data for venue : 70
# Retrieving data for venue : 71
# Retrieving data for venue : 72
# Retrieving data for venue : 73
# Retrieving data for venue : 74
# Retrieving data for venue : 75
# Retrieving data for venue : 76
# Retrieving data for venue : 77
# Retrieving data for venue : 78
# Retrieving data for venue : 79
# Retrieving data for venue : 80
# Retrieving data for venue : 81
# Retrieving data for venue : 82
# Retrieving data for venue : 83
# Retrieving data for venue : 84
# Retrieving data for venue : 85
# Retrieving data for venue : 86
# Retrieving data for venue : 87
# Retrieving data for venue : 88
# Retrieving data for venue : 89
# Retrieving data for venue : 90
# Retrieving data for venue : 91
# Retrieving data for venue : 92
# Retrieving data for venue : 93
# Retrieving data for venue : 94
# Retrieving data for venue : 95
# Retrieving data for venue : 96
# Retrieving data for venue : 97
# Retrieving data for venue : 98
# Retrieving data for venue : 99
# Retrieving data for venue : 100
# Retrieving data for venue : 101

# %%
z_venues = z_venues.dropna()
z_venues
# Out:
#                                   venue       latitude      longitude  \
# 0                                 Links  13.0798789882  80.2545083687
# 1            National Durbar Restaurant  13.0811536171  80.2707541734
# 2                    Mathura Restaurant  13.0663125835  80.2691274136
# 3                          Bombay Lassi  13.0658994398  80.2712054551
# 4                          Shree Mithai  13.0718078184  80.2480258048
# 5                        Tibb's Frankie  13.0555787887  80.2576834336
# 6                     Shadhi Ka Biryani  13.0637778627  80.2780025080
# 7                        The Cake World  13.0604275888  80.2545579895
# 8                       Cafe Coffee Day  13.0585825999  80.2642340586
# 9                Annalakshmi Restaurant  13.0717764660  80.2520588413
# 10                       Tibb's Frankie  13.0556199415  80.2577789873
# 11               Blend - Taj Club House  13.0613090896  80.2641837671
# 13                           The Marina  13.0667972508  80.2521513775
# 14                         Cream Centre  13.0672600353  80.2459893376
# 15                       Tibb's Frankie  13.0556199415  80.2577789873
# 16                        Writer's Cafe  13.0647300000  80.2582910000
# 17   Amadora Gourmet Ice Cream & Sorbet  13.0609073686  80.2495218068
# 18                        Welcome Hotel  13.0856211345  80.2546411380
# 19                         Krispy Kreme  13.0588945082  80.2639960125
# 20                            Nair Mess  13.0643634538  80.2776310220
# 21         Sandy's Chocolate Laboratory  13.0608763414  80.2483493462
# 22                      Blind Ch3mistry  13.0602038655  80.2494919673
# 23                         Kabab Corner  13.0599216798  80.2544808760
# 24                     Tuscana Pizzeria  13.0612862274  80.2499251440
# 25                    Novelty Tea House  13.0890017635  80.2789935842
# 26             Al-Najeeb Nawab Of Kebab  13.0878306969  80.2434958890
# 27                       Jonah's Bistro  13.0585156457  80.2650688961
# 28                            Cafe Amin  13.0512207970  80.2641472220
# 29                           Ratna Cafe  13.0583686731  80.2741776779
# 30                  Anmol Mohit Patiala  13.0903390454  80.2791431174
# ..                                  ...            ...            ...
# 71                            Sea Shore  13.0438424435  80.2805700526
# 72                          Al Kebabish  13.0853504079  80.2248679474
# 73                            Sea Shore  13.0438424435  80.2805700526
# 74                   Ahmadia Restaurant  13.0885279165  80.2823279053
# 75                        Karim Biryani  13.0839987297  80.2690838277
# 76                    New Central Hotel  13.0833286028  80.2762681246
# 77                                  KFC  13.0739374912  80.2217622846
# 78                       Madrasi Dawath  13.1136330000  80.2366290000
# 79                                  KFC  13.0739374912  80.2217622846
# 80                       Tibb's Frankie  13.0861312363  80.2567852288
# 81                             -3° Café  13.1088247961  80.2423083410
# 82                    Murugan Idli Shop  13.0812515899  80.2480207756
# 83                    Murugan Idli Shop  13.0812515899  80.2480207756
# 84                       Baskin Robbins  13.0826258167  80.2436849847
# 85                         Doveton Cafe  13.0864568256  80.2581283450
# 86                      Cafe Coffee Day  13.0789332178  80.2334718034
# 87                         Buhari Hotel  13.0839804416  80.2245346829
# 88                           Rang Mahal  13.0818054617  80.2544336021
# 89                 McCafe by McDonald's  13.0833430000  80.2402720000
# 90             Kovai Pazhamudir Nilayam  13.0854976910  80.2485880628
# 91             Virrundhu Veg Restaurant  13.0828330000  80.2782570000
# 92                   Bombay Halwa House  13.0852001855  80.2448269352
# 93                             Feastinn  13.0835496926  80.2349872515
# 94                              Jil Jil  13.1082399637  80.2916499227
# 95                            Sea Shore  13.0438424435  80.2805700526
# 96                       Kolkata Mithai  13.0653589228  80.2311493456
# 97                      Coco Jaunt 1728  13.0902440154  80.2175297588
# 98                       Jai Ice Creams  13.0619387777  80.2301388234
# 99            A2B - Adyar Ananda Bhavan  13.0842110014  80.2245755866
# 100               New Loyola Fast Foods  13.0666417916  80.2305015922
#
#      price_for_two  price_range rating  \
# 0            250.0          1.0    4.1
# 1            500.0          2.0    4.1
# 2            500.0          2.0    4.2
# 3            100.0          1.0    4.4
# 4            350.0          1.0    4.5
# 5            200.0          1.0    3.7
# 6            350.0          1.0      0
# 7            350.0          1.0    3.5
# 8            600.0          2.0    2.4
# 9           2000.0          4.0    4.1
# 10           200.0          1.0    3.8
# 11          5000.0          4.0    4.1
# 13          1600.0          3.0    4.6
# 14          1600.0          3.0    4.2
# 15           200.0          1.0    3.8
# 16           600.0          2.0    3.8
# 17           500.0          2.0    4.6
# 18           300.0          1.0    4.6
# 19           400.0          1.0    4.2
# 20           200.0          1.0    4.5
# 21          1400.0          3.0    4.3
# 22           700.0          2.0    4.2
# 23           450.0          1.0    4.6
# 24          1200.0          3.0    4.1
# 25           300.0          1.0    4.1
# 26           500.0          2.0    4.1
# 27           800.0          2.0    3.6
# 28           600.0          2.0    4.0
# 29           400.0          1.0    4.3
# 30           100.0          1.0    3.4
# ..             ...          ...    ...
# 71           150.0          1.0      0
# 72           400.0          1.0    4.1
# 73           150.0          1.0      0
# 74           300.0          1.0    2.8
# 75           300.0          1.0    4.0
# 76           200.0          1.0    3.1
# 77           500.0          2.0    4.0
# 78           250.0          1.0    3.2
# 79           500.0          2.0    4.0
# 80           200.0          1.0    3.2
# 81           200.0          1.0      0
# 82           200.0          1.0    3.8
# 83           200.0          1.0    3.8
# 84           200.0          1.0    3.4
# 85           400.0          1.0    4.0
# 86           600.0          2.0      0
# 87           850.0          2.0    4.1
# 88           800.0          2.0    3.9
# 89           500.0          2.0    3.3
# 90           200.0          1.0    3.9
# 91           300.0          1.0      0
# 92           500.0          2.0    4.3
# 93           300.0          1.0    4.1
# 94           200.0          1.0    3.3
# 95           150.0          1.0      0
# 96           200.0          1.0    2.9
# 97           650.0          2.0    3.9
# 98           150.0          1.0    4.1
# 99           600.0          2.0    3.8
# 100          250.0          1.0    3.8
#
#                                                address
# 0       22, Raja Annamalai Road, Purasavakkam, Chennai
# 1    3, Raja Muthiah Road, Near Central Railway Sta...
# 2    826, 2nd Floor, Tarapore Towers, Anna Salai, T...
# 3    8, Bahar Agan Street, Anna Salai, Ellis Road, ...
# 4                     18, Dr TV Road, Chetpet, Chennai
# 5    16, Thiru Vi Ka Road, Near Sathyam Cinemas Mai...
# 6    18/92, CN Krishna Swamy Road, Chepauk, Opposit...
# 7    11/2, Greams Road, Near Police Station, Thousa...
# 8    49/15, 3rd Floor, Express Avenue Mall, Whites ...
# 9    6, Mayor Ramanathan Salai, Spur Tank Road, Che...
# 10   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 11   Taj Club House Hotel, 2, Club House Road,  Ann...
# 13             39, College Road, Nungambakkam, Chennai
# 14   45, College Road, Near Madras Alliance Francai...
# 15   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 16   55/22, Doctor PV Cherian Crecent, Anna Salai, ...
# 17   23, Wallace Garden, 3rd Street, Nungambakkam, ...
# 18   112/241, Purasawalkam High Road, Purasavakkam,...
# 19   Upper Ground Floor, Express Avenue, Whites Roa...
# 20   22, Mohammed Abdullah, 2nd Street, Opposite Ch...
# 21   16, Wallace Garden, 2nd Street, Nungambakkam, ...
# 22   Old 11, New 19, 1st Floor, Brindhavan Apartmen...
# 23   12/1, Opposite Royal Enfield Showroom, Greams ...
# 24   19, 3rd Street, Wallace Garden Road, Nungambak...
# 25                175, Mint Street, Sowcarpet, Chennai
# 26   Families Complex, Medavakkam Tank Road, Kilpau...
# 27   Shop 4 B, 3rd Floor, Express Avenue, 49 50L, W...
# 28   21, Royapettah High Road, Near Royapettah Poli...
# 29      255, Triplicane High Road, Triplicane, Chennai
# 30   338, Mint Street, Near Kakada Ramprasad, Sowca...
# ..                                                 ...
# 71   Marina Beach, Near Gandhi Statue, Santhome, Ch...
# 72   6, D Block, 6th Street, Behind Chinthamani, An...
# 73   Marina Beach, Near Gandhi Statue, Santhome, Ch...
# 74               104, N.S.C Bose Road, Parrys, Chennai
# 75   11/1, Near Nehru Stadium, Samy Street, Periame...
# 76          159/160, Wall Tax Road, Park Town, Chennai
# 77   1, 627, Nelson Manickam Road, Aminijikarai, Ch...
# 78   9/4, 2nd Street, Tillai Nayagam Pillai, Peramb...
# 79   1, 627, Nelson Manickam Road, Aminijikarai, Ch...
# 80     Saravana Stores Building, Purasavakkam, Chennai
# 81         337/G8, Paper Mills Road, Perambur, Chennai
# 82            31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 83            31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 84   24, Balfour Road, Opposite Nagappa Motors, Kil...
# 85    5, Purasavakkam High Road, Purasavakkam, Chennai
# 86   64 & 64A, Ground Floor, New Avadi Road, Kilpau...
# 87   59, Block C, 1st Avenue, Anna Nagar East, Chennai
# 88   51, Gangadeshwar Koil Street, Purasavakkam, Ch...
# 89   226, Om Sakthi Plaza, Kilpauk Garden Road, Kil...
# 90   80/93, Palace Regency, Opposite Abirami Theatr...
# 91           9, Memorial Hall Road, Park Town, Chennai
# 92   12 & 14, 1st Floor, Balfour Road, Windsor Pala...
# 93   Shop 2, Door 262, Kilpauk Garden Road, Kilpauk...
# 94   73, G.E.C Tower, M.S Kovil Street, Royapuram, ...
# 95   Marina Beach, Near Gandhi Statue, Santhome, Ch...
# 96   Chitra Shopping Inn, 9A, Choolaimedu High Road...
# 97         T2, 4th Main Road, Anna Nagar East, Chennai
# 98   54/224, Choolaimedu High Road, Choolaimedu, Ch...
# 99   58, Plot 120, C Block, 1st Main Road, Chintham...
# 100  37/15, Nelson Manickam Road, Choolaimedu, Chennai
#
# [99 rows x 7 columns]

# %% [markdown]
# Now with the **venues retrieved and the data for each venue stored in the dataframe z_venues**, we can now visualize the locations of each venue on the map with the help of the folium library.

# %%
z_chennai_map = folium.Map(location = [chennai_latitude, chennai_longitude], zoom_start = 13)
for name, lat, lng in zip(z_venues['venue'], z_venues['latitude'], z_venues['longitude']):
    label = '{}'.format(name)
    latitude = float(lat)
    longitude = float(lng)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [latitude, longitude],
        radius = 5,
        popup = label,
        color = 'orange',
        fill = True,
        fill_color = 'orange',
        fill_opacity = 0.5,
        parse_html = False).add_to(z_chennai_map)  
z_chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# With the help of a lambda function we are **rounding the latitude & longitude values to 4  decimal digits** for both the ZomatoAPI data & the FoursquareAPI data.

# %%
fs_venues['lat'] = fs_venues['lat'].apply(lambda lat: round(float(lat), 4))
fs_venues['lng'] = fs_venues['lng'].apply(lambda lng: round(float(lng), 4))
z_venues['latitude'] = z_venues['latitude'].apply(lambda lat: round(float(lat), 4))
z_venues['longitude'] = z_venues['longitude'].apply(lambda lng: round(float(lng), 4))

# %% [markdown]
# Since we are using **2 dataframes -> fs_venues & z_venues**, there some **unwanted repeated data with slight deviations** in location. Therefor to remove this error we are **removing venues with a latitude & longitude difference greater than 0.0004.**

# %%
combine = pd.concat([fs_venues, z_venues], axis = 1)
combine['latitude_difference'] = combine['latitude'] - combine['lat']
combine['longitude_difference'] = combine['longitude'] - combine['lng']
filtered_venues = combine[(abs(combine['latitude_difference']) <= 0.0004) & (abs(combine['longitude_difference']) <= 0.0004)].reset_index(drop = True)
filtered_venues
# Out:
#                             name                      categories      lat  \
# 0                          Links                     Snack Place  13.0800
# 1          National Durbar Hotel               Indian Restaurant  13.0813
# 2       Mathura (woodland group)               Indian Restaurant  13.0666
# 3                   Bombay Lassi                    Dessert Shop  13.0660
# 4                   Shree Mithai               Indian Restaurant  13.0721
# 5      Fruit Shop On Greams Road                       Juice Bar  13.0604
# 6                 Express Avenue                   Shopping Mall  13.0587
# 7                Sathyam Cinemas                   Movie Theater  13.0555
# 8    Blend - The High Energy Bar                             Bar  13.0616
# 9                 Serene Sathyam                       Multiplex  13.0557
# 10     Amadora Gourmet Ice Cream                  Ice Cream Shop  13.0610
# 11                 Hotel Welcome                           Hotel  13.0857
# 12        Krispy Kreme Doughnuts                      Donut Shop  13.0590
# 13                     Nair Mess               Indian Restaurant  13.0645
# 14  Sandy's Chocolate Laboratory                  Chocolate Shop  13.0611
# 15                  Kabab Corner                Kebab Restaurant  13.0602
# 16              Tuscana Pizzeria              Italian Restaurant  13.0615
# 17    AL - NAJEEB Nawab Of Kabab                            Food  13.0878
# 18                    Ratna cafe               Indian Restaurant  13.0587
# 19              Kakada Ramprasad               Indian Restaurant  13.0904
# 20                Taj Coromandel                           Hotel  13.0584
# 21                 Cream & Fudge                  Ice Cream Shop  13.0610
# 22                       Dynasty              Chinese Restaurant  13.0669
# 23                Hotel Crescent  Multicuisine Indian Restaurant  13.0644
# 24            Kasi Vinayaga Mess               Indian Restaurant  13.0608
# 25  Z The Tapas Bar & Restaurant                             Bar  13.0458
# 26                        Dahlia             Japanese Restaurant  13.0624
# 27          Basil - With a Twist      Modern European Restaurant  13.0496
# 28   Sea Shell Family Restaurant       Middle Eastern Restaurant  13.0571
# 29                  Ente Keralam               Kerala Restaurant  13.0422
# 30            Ajnabi Mithai Ghar            Fast Food Restaurant  13.0679
# 31                       Zaitoon       Middle Eastern Restaurant  13.0835
# 32                         Ibaco                  Ice Cream Shop  13.0497
# 33    A2B Restaurant Chinthamani               Indian Restaurant  13.0843
# 34                   Coffeetales                     Coffee Shop  13.0819
# 35               Kailash Kitchen              Chinese Restaurant  13.0655
# 36               Hotel Paramount               Indian Restaurant  13.0816
# 37         Hotel Saravana Bhavan               Indian Restaurant  13.0854
# 38                   Al-Kebabish                      Restaurant  13.0852
# 39               Saravana Stores                Department Store  13.0865
# 40                 Perambur Park                      Theme Park  13.1090
# 41            Murugan Idli Kadai               Indian Restaurant  13.0813
# 42             Murugan Idly Shop               Indian Restaurant  13.0815
# 43                  Doveton Cafe               Indian Restaurant  13.0868
# 44                  Buhari Hotel               Indian Restaurant  13.0841
# 45             Novelty Tea House               Indian Restaurant  13.0819
# 46               cafe coffee day                     Coffee Shop  13.0836
# 47            Bombay Halwa House               Indian Restaurant  13.0853
# 48           MILKY Way Royapuram                  Ice Cream Shop  13.1084
# 49         Nike Store Anna Nagar             Sporting Goods Shop  13.0844
# 50             Loyola fast foods            Fast Food Restaurant  13.0667
#
#         lng                               venue  latitude  longitude  \
# 0   80.2546                               Links   13.0799    80.2545
# 1   80.2706          National Durbar Restaurant   13.0812    80.2708
# 2   80.2690                  Mathura Restaurant   13.0663    80.2691
# 3   80.2712                        Bombay Lassi   13.0659    80.2712
# 4   80.2479                        Shree Mithai   13.0718    80.2480
# 5   80.2544                      The Cake World   13.0604    80.2546
# 6   80.2642                     Cafe Coffee Day   13.0586    80.2642
# 7   80.2580                      Tibb's Frankie   13.0556    80.2578
# 8   80.2644              Blend - Taj Club House   13.0613    80.2642
# 9   80.2580                      Tibb's Frankie   13.0556    80.2578
# 10  80.2495  Amadora Gourmet Ice Cream & Sorbet   13.0609    80.2495
# 11  80.2546                       Welcome Hotel   13.0856    80.2546
# 12  80.2641                        Krispy Kreme   13.0589    80.2640
# 13  80.2776                           Nair Mess   13.0644    80.2776
# 14  80.2484        Sandy's Chocolate Laboratory   13.0609    80.2483
# 15  80.2545                        Kabab Corner   13.0599    80.2545
# 16  80.2498                    Tuscana Pizzeria   13.0613    80.2499
# 17  80.2434            Al-Najeeb Nawab Of Kebab   13.0878    80.2435
# 18  80.2742                          Ratna Cafe   13.0584    80.2742
# 19  80.2791                 Anmol Mohit Patiala   13.0903    80.2791
# 20  80.2474      Golden Dragon - Taj Coromandel   13.0585    80.2475
# 21  80.2515                       Cream & Fudge   13.0607    80.2515
# 22  80.2431                             Dynasty   13.0666    80.2429
# 23  80.2434                  Hotel Raaj Bhaavan   13.0641    80.2435
# 24  80.2770                   Kasivinayaga Mess   13.0608    80.2769
# 25  80.2580   Sera - The Tapas Bar & Restaurant   13.0456    80.2580
# 26  80.2453                              Dahlia   13.0625    80.2452
# 27  80.2422                  Basil With A Twist   13.0497    80.2423
# 28  80.2551                   Savoury Sea Shell   13.0572    80.2552
# 29  80.2559                        Ente Keralam   13.0422    80.2559
# 30  80.2564                             Ajanabi   13.0677    80.2565
# 31  80.2255                             Zaitoon   13.0835    80.2255
# 32  80.2402                               ibaco   13.0500    80.2401
# 33  80.2247           A2B - Adyar Ananda Bhavan   13.0842    80.2246
# 34  80.2249                         Coffeetales   13.0818    80.2250
# 35  80.2311    Momo Sa-Khang by Kailash Kitchen   13.0654    80.2310
# 36  80.2476                     Hotel Paramount   13.0814    80.2477
# 37  80.2521               Hotel Saravana Bhavan   13.0852    80.2522
# 38  80.2250                         Al Kebabish   13.0854    80.2249
# 39  80.2570                      Tibb's Frankie   13.0861    80.2568
# 40  80.2426                            -3° Café   13.1088    80.2423
# 41  80.2480                   Murugan Idli Shop   13.0813    80.2480
# 42  80.2479                   Murugan Idli Shop   13.0813    80.2480
# 43  80.2581                        Doveton Cafe   13.0865    80.2581
# 44  80.2246                        Buhari Hotel   13.0840    80.2245
# 45  80.2543                          Rang Mahal   13.0818    80.2544
# 46  80.2401                McCafe by McDonald's   13.0833    80.2403
# 47  80.2451                  Bombay Halwa House   13.0852    80.2448
# 48  80.2917                             Jil Jil   13.1082    80.2916
# 49  80.2249           A2B - Adyar Ananda Bhavan   13.0842    80.2246
# 50  80.2304               New Loyola Fast Foods   13.0666    80.2305
#
#     price_for_two  price_range rating  \
# 0           250.0          1.0    4.1
# 1           500.0          2.0    4.1
# 2           500.0          2.0    4.2
# 3           100.0          1.0    4.4
# 4           350.0          1.0    4.5
# 5           350.0          1.0    3.5
# 6           600.0          2.0    2.4
# 7           200.0          1.0    3.8
# 8          5000.0          4.0    4.1
# 9           200.0          1.0    3.8
# 10          500.0          2.0    4.6
# 11          300.0          1.0    4.6
# 12          400.0          1.0    4.2
# 13          200.0          1.0    4.5
# 14         1400.0          3.0    4.3
# 15          450.0          1.0    4.6
# 16         1200.0          3.0    4.1
# 17          500.0          2.0    4.1
# 18          400.0          1.0    4.3
# 19          100.0          1.0    3.4
# 20         2800.0          4.0    4.4
# 21          350.0          1.0    4.0
# 22         1200.0          3.0    4.2
# 23          600.0          2.0    3.9
# 24          200.0          1.0    4.1
# 25         1600.0          3.0    4.0
# 26         1500.0          3.0    4.2
# 27         1500.0          3.0    4.1
# 28          750.0          2.0    4.2
# 29          750.0          2.0    4.4
# 30          250.0          1.0    4.3
# 31          900.0          2.0    4.2
# 32          200.0          1.0    4.3
# 33          600.0          2.0    3.8
# 34          500.0          2.0    4.2
# 35          350.0          1.0    4.6
# 36          500.0          2.0    4.2
# 37          550.0          2.0    3.2
# 38          400.0          1.0    4.1
# 39          200.0          1.0    3.2
# 40          200.0          1.0      0
# 41          200.0          1.0    3.8
# 42          200.0          1.0    3.8
# 43          400.0          1.0    4.0
# 44          850.0          2.0    4.1
# 45          800.0          2.0    3.9
# 46          500.0          2.0    3.3
# 47          500.0          2.0    4.3
# 48          200.0          1.0    3.3
# 49          600.0          2.0    3.8
# 50          250.0          1.0    3.8
#
#                                               address  latitude_difference  \
# 0      22, Raja Annamalai Road, Purasavakkam, Chennai              -0.0001
# 1   3, Raja Muthiah Road, Near Central Railway Sta...              -0.0001
# 2   826, 2nd Floor, Tarapore Towers, Anna Salai, T...              -0.0003
# 3   8, Bahar Agan Street, Anna Salai, Ellis Road, ...              -0.0001
# 4                    18, Dr TV Road, Chetpet, Chennai              -0.0003
# 5   11/2, Greams Road, Near Police Station, Thousa...               0.0000
# 6   49/15, 3rd Floor, Express Avenue Mall, Whites ...              -0.0001
# 7   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...               0.0001
# 8   Taj Club House Hotel, 2, Club House Road,  Ann...              -0.0003
# 9   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...              -0.0001
# 10  23, Wallace Garden, 3rd Street, Nungambakkam, ...              -0.0001
# 11  112/241, Purasawalkam High Road, Purasavakkam,...              -0.0001
# 12  Upper Ground Floor, Express Avenue, Whites Roa...              -0.0001
# 13  22, Mohammed Abdullah, 2nd Street, Opposite Ch...              -0.0001
# 14  16, Wallace Garden, 2nd Street, Nungambakkam, ...              -0.0002
# 15  12/1, Opposite Royal Enfield Showroom, Greams ...              -0.0003
# 16  19, 3rd Street, Wallace Garden Road, Nungambak...              -0.0002
# 17  Families Complex, Medavakkam Tank Road, Kilpau...               0.0000
# 18     255, Triplicane High Road, Triplicane, Chennai              -0.0003
# 19  338, Mint Street, Near Kakada Ramprasad, Sowca...              -0.0001
# 20  37, Taj Coromandel, Mahatma Gandhi Road, Nunga...               0.0001
# 21  10, Khader Nawaz Khan Road, Opposite Evoluzion...              -0.0003
# 22  315, Harrisons Hotel, Valluvar Kottam High Roa...              -0.0003
# 23  307, Valluvar Kottam High Road, Nungambakkam, ...              -0.0003
# 24      58/2, Akbar Saheb Street, Triplicane, Chennai               0.0000
# 25           71, Cathedral Road, Gopalapuram, Chennai              -0.0002
# 26          37, Kaveri Complex, Nungambakkam, Chennai               0.0001
# 27           58-A, Habibullah Road, T. Nagar, Chennai               0.0001
# 28  55, Ali Tower, Greams Road, Opposite IDBI Bank...               0.0001
# 29  1, Poes Garden, Kasturi Estate, 1st Street, Al...               0.0000
# 30  149, Fountain Plaza, Pantheon Road, Egmore, Ch...              -0.0002
# 31  119, D Block, 1st Main Road, Chintamani, Oppos...               0.0000
# 32  No:140,Habibullah Road,Opp To Vidhyodaya Schoo...               0.0003
# 33  58, Plot 120, C Block, 1st Main Road, Chintham...              -0.0001
# 34  7, 7th Cross Street, Near Thiru Vee Ka Park, A...              -0.0001
# 35  2/247, Perinbavilas Complex, Opposite Chitra A...              -0.0001
# 36                 12/5, Ormes Road, Kilpauk, Chennai              -0.0002
# 37           1, Vellala Street, Purasavakkam, Chennai              -0.0002
# 38  6, D Block, 6th Street, Behind Chinthamani, An...               0.0002
# 39    Saravana Stores Building, Purasavakkam, Chennai              -0.0004
# 40        337/G8, Paper Mills Road, Perambur, Chennai              -0.0002
# 41           31 & 12/3A, Ormes Road, Kilpauk, Chennai               0.0000
# 42           31 & 12/3A, Ormes Road, Kilpauk, Chennai              -0.0002
# 43   5, Purasavakkam High Road, Purasavakkam, Chennai              -0.0003
# 44  59, Block C, 1st Avenue, Anna Nagar East, Chennai              -0.0001
# 45  51, Gangadeshwar Koil Street, Purasavakkam, Ch...              -0.0001
# 46  226, Om Sakthi Plaza, Kilpauk Garden Road, Kil...              -0.0003
# 47  12 & 14, 1st Floor, Balfour Road, Windsor Pala...              -0.0001
# 48  73, G.E.C Tower, M.S Kovil Street, Royapuram, ...              -0.0002
# 49  58, Plot 120, C Block, 1st Main Road, Chintham...              -0.0002
# 50  37/15, Nelson Manickam Road, Choolaimedu, Chennai              -0.0001
#
#     longitude_difference
# 0                -0.0001
# 1                 0.0002
# 2                 0.0001
# 3                 0.0000
# 4                 0.0001
# 5                 0.0002
# 6                 0.0000
# 7                -0.0002
# 8                -0.0002
# 9                -0.0002
# 10                0.0000
# 11                0.0000
# 12               -0.0001
# 13                0.0000
# 14               -0.0001
# 15                0.0000
# 16                0.0001
# 17                0.0001
# 18                0.0000
# 19                0.0000
# 20                0.0001
# 21                0.0000
# 22               -0.0002
# 23                0.0001
# 24               -0.0001
# 25                0.0000
# 26               -0.0001
# 27                0.0001
# 28                0.0001
# 29                0.0000
# 30                0.0001
# 31                0.0000
# 32               -0.0001
# 33               -0.0001
# 34                0.0001
# 35               -0.0001
# 36                0.0001
# 37                0.0001
# 38               -0.0001
# 39               -0.0002
# 40               -0.0003
# 41                0.0000
# 42                0.0001
# 43                0.0000
# 44               -0.0001
# 45                0.0001
# 46                0.0002
# 47               -0.0003
# 48               -0.0001
# 49               -0.0003
# 50                0.0001

# %% [markdown]
# Since we have a dataframe result with repeated columns after combining of both the dataframes, we must remove the repeated ones.

# %%
filtered_venues = filtered_venues.drop(columns = ['name', 'lat', 'lng', 'latitude_difference', 'longitude_difference'])

# %% [markdown]
# **Removing** the venues which have **0 rating (They are unrated)**.

# %%
filtered_venues = filtered_venues[filtered_venues['rating'] != 0.0]
print("Total venues available: {}".format(filtered_venues.shape[0]))
filtered_venues.head()
# Out:
# Total venues available: 50
#           categories                       venue  latitude  longitude  \
# 0        Snack Place                       Links   13.0799    80.2545
# 1  Indian Restaurant  National Durbar Restaurant   13.0812    80.2708
# 2  Indian Restaurant          Mathura Restaurant   13.0663    80.2691
# 3       Dessert Shop                Bombay Lassi   13.0659    80.2712
# 4  Indian Restaurant                Shree Mithai   13.0718    80.2480
#
#    price_for_two  price_range rating  \
# 0          250.0          1.0    4.1
# 1          500.0          2.0    4.1
# 2          500.0          2.0    4.2
# 3          100.0          1.0    4.4
# 4          350.0          1.0    4.5
#
#                                              address
# 0     22, Raja Annamalai Road, Purasavakkam, Chennai
# 1  3, Raja Muthiah Road, Near Central Railway Sta...
# 2  826, 2nd Floor, Tarapore Towers, Anna Salai, T...
# 3  8, Bahar Agan Street, Anna Salai, Ellis Road, ...
# 4                   18, Dr TV Road, Chetpet, Chennai

# %% [markdown]
# **Renaming columns**, so the data can be understood easily.

# %%
data = filtered_venues.rename(columns = {'categories':'Category','venue':'Venue Name','latitude':'Latitude','longitude':'Longitude','price_for_two':'Price','price_range':'Price Range','rating':'Rating','address':'Venue Address'})
data
# Out:
#                           Category                          Venue Name  \
# 0                      Snack Place                               Links
# 1                Indian Restaurant          National Durbar Restaurant
# 2                Indian Restaurant                  Mathura Restaurant
# 3                     Dessert Shop                        Bombay Lassi
# 4                Indian Restaurant                        Shree Mithai
# 5                        Juice Bar                      The Cake World
# 6                    Shopping Mall                     Cafe Coffee Day
# 7                    Movie Theater                      Tibb's Frankie
# 8                              Bar              Blend - Taj Club House
# 9                        Multiplex                      Tibb's Frankie
# 10                  Ice Cream Shop  Amadora Gourmet Ice Cream & Sorbet
# 11                           Hotel                       Welcome Hotel
# 12                      Donut Shop                        Krispy Kreme
# 13               Indian Restaurant                           Nair Mess
# 14                  Chocolate Shop        Sandy's Chocolate Laboratory
# 15                Kebab Restaurant                        Kabab Corner
# 16              Italian Restaurant                    Tuscana Pizzeria
# 17                            Food            Al-Najeeb Nawab Of Kebab
# 18               Indian Restaurant                          Ratna Cafe
# 19               Indian Restaurant                 Anmol Mohit Patiala
# 20                           Hotel      Golden Dragon - Taj Coromandel
# 21                  Ice Cream Shop                       Cream & Fudge
# 22              Chinese Restaurant                             Dynasty
# 23  Multicuisine Indian Restaurant                  Hotel Raaj Bhaavan
# 24               Indian Restaurant                   Kasivinayaga Mess
# 25                             Bar   Sera - The Tapas Bar & Restaurant
# 26             Japanese Restaurant                              Dahlia
# 27      Modern European Restaurant                  Basil With A Twist
# 28       Middle Eastern Restaurant                   Savoury Sea Shell
# 29               Kerala Restaurant                        Ente Keralam
# 30            Fast Food Restaurant                             Ajanabi
# 31       Middle Eastern Restaurant                             Zaitoon
# 32                  Ice Cream Shop                               ibaco
# 33               Indian Restaurant           A2B - Adyar Ananda Bhavan
# 34                     Coffee Shop                         Coffeetales
# 35              Chinese Restaurant    Momo Sa-Khang by Kailash Kitchen
# 36               Indian Restaurant                     Hotel Paramount
# 37               Indian Restaurant               Hotel Saravana Bhavan
# 38                      Restaurant                         Al Kebabish
# 39                Department Store                      Tibb's Frankie
# 41               Indian Restaurant                   Murugan Idli Shop
# 42               Indian Restaurant                   Murugan Idli Shop
# 43               Indian Restaurant                        Doveton Cafe
# 44               Indian Restaurant                        Buhari Hotel
# 45               Indian Restaurant                          Rang Mahal
# 46                     Coffee Shop                McCafe by McDonald's
# 47               Indian Restaurant                  Bombay Halwa House
# 48                  Ice Cream Shop                             Jil Jil
# 49             Sporting Goods Shop           A2B - Adyar Ananda Bhavan
# 50            Fast Food Restaurant               New Loyola Fast Foods
#
#     Latitude  Longitude   Price  Price Range Rating  \
# 0    13.0799    80.2545   250.0          1.0    4.1
# 1    13.0812    80.2708   500.0          2.0    4.1
# 2    13.0663    80.2691   500.0          2.0    4.2
# 3    13.0659    80.2712   100.0          1.0    4.4
# 4    13.0718    80.2480   350.0          1.0    4.5
# 5    13.0604    80.2546   350.0          1.0    3.5
# 6    13.0586    80.2642   600.0          2.0    2.4
# 7    13.0556    80.2578   200.0          1.0    3.8
# 8    13.0613    80.2642  5000.0          4.0    4.1
# 9    13.0556    80.2578   200.0          1.0    3.8
# 10   13.0609    80.2495   500.0          2.0    4.6
# 11   13.0856    80.2546   300.0          1.0    4.6
# 12   13.0589    80.2640   400.0          1.0    4.2
# 13   13.0644    80.2776   200.0          1.0    4.5
# 14   13.0609    80.2483  1400.0          3.0    4.3
# 15   13.0599    80.2545   450.0          1.0    4.6
# 16   13.0613    80.2499  1200.0          3.0    4.1
# 17   13.0878    80.2435   500.0          2.0    4.1
# 18   13.0584    80.2742   400.0          1.0    4.3
# 19   13.0903    80.2791   100.0          1.0    3.4
# 20   13.0585    80.2475  2800.0          4.0    4.4
# 21   13.0607    80.2515   350.0          1.0    4.0
# 22   13.0666    80.2429  1200.0          3.0    4.2
# 23   13.0641    80.2435   600.0          2.0    3.9
# 24   13.0608    80.2769   200.0          1.0    4.1
# 25   13.0456    80.2580  1600.0          3.0    4.0
# 26   13.0625    80.2452  1500.0          3.0    4.2
# 27   13.0497    80.2423  1500.0          3.0    4.1
# 28   13.0572    80.2552   750.0          2.0    4.2
# 29   13.0422    80.2559   750.0          2.0    4.4
# 30   13.0677    80.2565   250.0          1.0    4.3
# 31   13.0835    80.2255   900.0          2.0    4.2
# 32   13.0500    80.2401   200.0          1.0    4.3
# 33   13.0842    80.2246   600.0          2.0    3.8
# 34   13.0818    80.2250   500.0          2.0    4.2
# 35   13.0654    80.2310   350.0          1.0    4.6
# 36   13.0814    80.2477   500.0          2.0    4.2
# 37   13.0852    80.2522   550.0          2.0    3.2
# 38   13.0854    80.2249   400.0          1.0    4.1
# 39   13.0861    80.2568   200.0          1.0    3.2
# 41   13.0813    80.2480   200.0          1.0    3.8
# 42   13.0813    80.2480   200.0          1.0    3.8
# 43   13.0865    80.2581   400.0          1.0    4.0
# 44   13.0840    80.2245   850.0          2.0    4.1
# 45   13.0818    80.2544   800.0          2.0    3.9
# 46   13.0833    80.2403   500.0          2.0    3.3
# 47   13.0852    80.2448   500.0          2.0    4.3
# 48   13.1082    80.2916   200.0          1.0    3.3
# 49   13.0842    80.2246   600.0          2.0    3.8
# 50   13.0666    80.2305   250.0          1.0    3.8
#
#                                         Venue Address
# 0      22, Raja Annamalai Road, Purasavakkam, Chennai
# 1   3, Raja Muthiah Road, Near Central Railway Sta...
# 2   826, 2nd Floor, Tarapore Towers, Anna Salai, T...
# 3   8, Bahar Agan Street, Anna Salai, Ellis Road, ...
# 4                    18, Dr TV Road, Chetpet, Chennai
# 5   11/2, Greams Road, Near Police Station, Thousa...
# 6   49/15, 3rd Floor, Express Avenue Mall, Whites ...
# 7   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 8   Taj Club House Hotel, 2, Club House Road,  Ann...
# 9   16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 10  23, Wallace Garden, 3rd Street, Nungambakkam, ...
# 11  112/241, Purasawalkam High Road, Purasavakkam,...
# 12  Upper Ground Floor, Express Avenue, Whites Roa...
# 13  22, Mohammed Abdullah, 2nd Street, Opposite Ch...
# 14  16, Wallace Garden, 2nd Street, Nungambakkam, ...
# 15  12/1, Opposite Royal Enfield Showroom, Greams ...
# 16  19, 3rd Street, Wallace Garden Road, Nungambak...
# 17  Families Complex, Medavakkam Tank Road, Kilpau...
# 18     255, Triplicane High Road, Triplicane, Chennai
# 19  338, Mint Street, Near Kakada Ramprasad, Sowca...
# 20  37, Taj Coromandel, Mahatma Gandhi Road, Nunga...
# 21  10, Khader Nawaz Khan Road, Opposite Evoluzion...
# 22  315, Harrisons Hotel, Valluvar Kottam High Roa...
# 23  307, Valluvar Kottam High Road, Nungambakkam, ...
# 24      58/2, Akbar Saheb Street, Triplicane, Chennai
# 25           71, Cathedral Road, Gopalapuram, Chennai
# 26          37, Kaveri Complex, Nungambakkam, Chennai
# 27           58-A, Habibullah Road, T. Nagar, Chennai
# 28  55, Ali Tower, Greams Road, Opposite IDBI Bank...
# 29  1, Poes Garden, Kasturi Estate, 1st Street, Al...
# 30  149, Fountain Plaza, Pantheon Road, Egmore, Ch...
# 31  119, D Block, 1st Main Road, Chintamani, Oppos...
# 32  No:140,Habibullah Road,Opp To Vidhyodaya Schoo...
# 33  58, Plot 120, C Block, 1st Main Road, Chintham...
# 34  7, 7th Cross Street, Near Thiru Vee Ka Park, A...
# 35  2/247, Perinbavilas Complex, Opposite Chitra A...
# 36                 12/5, Ormes Road, Kilpauk, Chennai
# 37           1, Vellala Street, Purasavakkam, Chennai
# 38  6, D Block, 6th Street, Behind Chinthamani, An...
# 39    Saravana Stores Building, Purasavakkam, Chennai
# 41           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 42           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 43   5, Purasavakkam High Road, Purasavakkam, Chennai
# 44  59, Block C, 1st Avenue, Anna Nagar East, Chennai
# 45  51, Gangadeshwar Koil Street, Purasavakkam, Ch...
# 46  226, Om Sakthi Plaza, Kilpauk Garden Road, Kil...
# 47  12 & 14, 1st Floor, Balfour Road, Windsor Pala...
# 48  73, G.E.C Tower, M.S Kovil Street, Royapuram, ...
# 49  58, Plot 120, C Block, 1st Main Road, Chintham...
# 50  37/15, Nelson Manickam Road, Choolaimedu, Chennai

# %% [markdown]
# Visualizing the cleaned data on a map with the help of the folium library.

# %%
filtered_chennai_map = folium.Map(location = [chennai_latitude, chennai_longitude], zoom_start = 13)
for name, lat, lng in zip(data['Venue Name'], data['Latitude'],data['Longitude']):
    label = '{}'.format(name)
    label = folium.Popup(label, parse_html = True)
    folium.CircleMarker(
        [lat, lng],
        radius = 5,
        popup = label,
        color = 'black',
        fill = True,
        fill_color = 'grey',
        fill_opacity = 0.7,
        parse_html = False).add_to(filtered_chennai_map)  
filtered_chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# This **concludes the data gathering & data cleaning phase**. We have combined the data we acquired from both the dataframes -> ZomatoAPI & FoursquareAPI. We removed the data which had slight differences in latitude & longitude. We removed venues which had 0 rating (unrated). The obtained dataframe **"data"** is visualized in the above map.

# %% [markdown]
# # Methodology

# %% [markdown]
# In this project, we are focusing on **venues tourists can visit during their stay in Chennai**. We will be directing our efforts to **analyze venues with similar ratings & pricing**. We are limiting our analysis to a **5Km range** around Chennai.
#
# In first step we have collected the required **data: location, rating & pricing of every venue within 5km of Chennai**. We have cleaned the data by **removing repeated locations & unrated venues**.
#
# Second step in our analysis will be calculation and exploration of '**Rating & Pricing**' of each venue. With the help of **bar plots** we will be visualizing **the Number of venue categories & Number of ratings within 5Km of Chennai**. We will also visualize the **venue count vs. pricing** with the help of a **scatter plot**.
#
# In third and final step we will focus on **identifying groups with the help of clustering (Affinity Propagation Clustering)**. The clusters will then be created and will describe **a group of venues with similar ratings & price ranges**. This will **help the tourist to identify where he or she would want to visit according to the venue's rating & the tourist's budget**.

# %% [markdown]
# # Analysis

# %% [markdown]
# Lets perform some basic exploratory data analysis & try to acquire some additional information about the venues. First lets **visualize the number of venue categories within the 5km radius of Chennai**.

# %%
venue_graph = data['Category'].value_counts()
colors = cm.viridis(np.linspace(0, 1, len(venue_graph.index)))
plt.figure(figsize = (15, 8))
plt.xticks(rotation = 90)
plt.xlabel('Venue category', fontsize = 17)
plt.ylabel('Count', fontsize = 17)
plt.bar(venue_graph.index, venue_graph.values, color = colors)
# Out:
# <BarContainer object of 26 artists>

# %% [markdown]
# Let us replace the categories with numerical values :
# * **Leisure places - 0**
# * **Restaurants - 1**
# * **Quick eats -2**

# %%
data = data.replace(['Sporting Goods Shop','Department Store','Multiplex','Hotel','Bar','Movie Theater','Gaming Cafe','Shopping Mall','Park','Concert Hall','Pool','Café'],0)
data = data.replace(['Indian Restaurant','Japanese Restaurant','Fast Food Restaurant','Middle Eastern Restaurant','Restaurant','Italian Restaurant','Chinese Restaurant','Modern European Restaurant','BBQ Joint',
                     'Vegetarian / Vegan Restaurant','Seafood Restaurant','Food','Kebab Restaurant','Hyderabadi Restaurant','Multicuisine Indian Restaurant','Korean Restaurant','Kerala Restaurant','Asian Restaurant','Comfort Food Restaurant'],1)
data = data.replace(['Ice Cream Shop','Coffee Shop','Juice Bar','Dessert Shop','Bakery','Frozen Yogurt Shop','Donut Shop','Chocolate Shop','Snack Place','Sandwich Place'],2)
data['Category'].value_counts()
# Out:
# 1    30
# 2    11
# 0     9
# Name: Category, dtype: int64

# %% [markdown]
# From the above bar plot, it is obvious that there are a **lot of Indian Restaurants within the 5Km radius**. This is **good for tourists who want to try the local cuisine & experience the culture of Chennai**.

# %% [markdown]
# Now lets **visualize the number of counts for each rating**, where  **0 is the least & 5 is the highest rating**.

# %%
data['Rating'] = data['Rating'].astype(float)
rating = data['Rating'].value_counts().sort_index()
plt.figure(figsize = (15,8))
plt.bar(rating.index, rating.values, color = cm.plasma(np.linspace(0, 1, len(rating.index))))
plt.xlabel('Rating', fontsize = 17)
plt.ylabel('Count', fontsize = 17)
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# From the above bar plot, we can conclude that there are a **lot of venues with an average rating of 3.5-4.5**. This is **good for tourism, the rating indicates the customer/visitor satisfaction of the venue**.

# %% [markdown]
# In-order **to visualize the rating on the map, let us group the Rating into bins** where :
# * 0-2.5    is **Bad**
# * 2.5-3.2   is **Average**
# * 3.2-4.2 is **Good**
# * 4.2-5.0 is **Excellent**

# %%
bins = [0, 2.5, 3.2, 4.2, 5.0]
labels = ['Bad', 'Average', 'Good', 'Excellent']
data['Review'] = pd.cut(data['Rating'].astype(float), bins = bins, labels = labels, include_lowest = True)
data
# Out:
#     Category                          Venue Name  Latitude  Longitude   Price  \
# 0          2                               Links   13.0799    80.2545   250.0
# 1          1          National Durbar Restaurant   13.0812    80.2708   500.0
# 2          1                  Mathura Restaurant   13.0663    80.2691   500.0
# 3          2                        Bombay Lassi   13.0659    80.2712   100.0
# 4          1                        Shree Mithai   13.0718    80.2480   350.0
# 5          2                      The Cake World   13.0604    80.2546   350.0
# 6          0                     Cafe Coffee Day   13.0586    80.2642   600.0
# 7          0                      Tibb's Frankie   13.0556    80.2578   200.0
# 8          0              Blend - Taj Club House   13.0613    80.2642  5000.0
# 9          0                      Tibb's Frankie   13.0556    80.2578   200.0
# 10         2  Amadora Gourmet Ice Cream & Sorbet   13.0609    80.2495   500.0
# 11         0                       Welcome Hotel   13.0856    80.2546   300.0
# 12         2                        Krispy Kreme   13.0589    80.2640   400.0
# 13         1                           Nair Mess   13.0644    80.2776   200.0
# 14         2        Sandy's Chocolate Laboratory   13.0609    80.2483  1400.0
# 15         1                        Kabab Corner   13.0599    80.2545   450.0
# 16         1                    Tuscana Pizzeria   13.0613    80.2499  1200.0
# 17         1            Al-Najeeb Nawab Of Kebab   13.0878    80.2435   500.0
# 18         1                          Ratna Cafe   13.0584    80.2742   400.0
# 19         1                 Anmol Mohit Patiala   13.0903    80.2791   100.0
# 20         0      Golden Dragon - Taj Coromandel   13.0585    80.2475  2800.0
# 21         2                       Cream & Fudge   13.0607    80.2515   350.0
# 22         1                             Dynasty   13.0666    80.2429  1200.0
# 23         1                  Hotel Raaj Bhaavan   13.0641    80.2435   600.0
# 24         1                   Kasivinayaga Mess   13.0608    80.2769   200.0
# 25         0   Sera - The Tapas Bar & Restaurant   13.0456    80.2580  1600.0
# 26         1                              Dahlia   13.0625    80.2452  1500.0
# 27         1                  Basil With A Twist   13.0497    80.2423  1500.0
# 28         1                   Savoury Sea Shell   13.0572    80.2552   750.0
# 29         1                        Ente Keralam   13.0422    80.2559   750.0
# 30         1                             Ajanabi   13.0677    80.2565   250.0
# 31         1                             Zaitoon   13.0835    80.2255   900.0
# 32         2                               ibaco   13.0500    80.2401   200.0
# 33         1           A2B - Adyar Ananda Bhavan   13.0842    80.2246   600.0
# 34         2                         Coffeetales   13.0818    80.2250   500.0
# 35         1    Momo Sa-Khang by Kailash Kitchen   13.0654    80.2310   350.0
# 36         1                     Hotel Paramount   13.0814    80.2477   500.0
# 37         1               Hotel Saravana Bhavan   13.0852    80.2522   550.0
# 38         1                         Al Kebabish   13.0854    80.2249   400.0
# 39         0                      Tibb's Frankie   13.0861    80.2568   200.0
# 41         1                   Murugan Idli Shop   13.0813    80.2480   200.0
# 42         1                   Murugan Idli Shop   13.0813    80.2480   200.0
# 43         1                        Doveton Cafe   13.0865    80.2581   400.0
# 44         1                        Buhari Hotel   13.0840    80.2245   850.0
# 45         1                          Rang Mahal   13.0818    80.2544   800.0
# 46         2                McCafe by McDonald's   13.0833    80.2403   500.0
# 47         1                  Bombay Halwa House   13.0852    80.2448   500.0
# 48         2                             Jil Jil   13.1082    80.2916   200.0
# 49         0           A2B - Adyar Ananda Bhavan   13.0842    80.2246   600.0
# 50         1               New Loyola Fast Foods   13.0666    80.2305   250.0
#
#     Price Range  Rating                                      Venue Address  \
# 0           1.0     4.1     22, Raja Annamalai Road, Purasavakkam, Chennai
# 1           2.0     4.1  3, Raja Muthiah Road, Near Central Railway Sta...
# 2           2.0     4.2  826, 2nd Floor, Tarapore Towers, Anna Salai, T...
# 3           1.0     4.4  8, Bahar Agan Street, Anna Salai, Ellis Road, ...
# 4           1.0     4.5                   18, Dr TV Road, Chetpet, Chennai
# 5           1.0     3.5  11/2, Greams Road, Near Police Station, Thousa...
# 6           2.0     2.4  49/15, 3rd Floor, Express Avenue Mall, Whites ...
# 7           1.0     3.8  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 8           4.0     4.1  Taj Club House Hotel, 2, Club House Road,  Ann...
# 9           1.0     3.8  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 10          2.0     4.6  23, Wallace Garden, 3rd Street, Nungambakkam, ...
# 11          1.0     4.6  112/241, Purasawalkam High Road, Purasavakkam,...
# 12          1.0     4.2  Upper Ground Floor, Express Avenue, Whites Roa...
# 13          1.0     4.5  22, Mohammed Abdullah, 2nd Street, Opposite Ch...
# 14          3.0     4.3  16, Wallace Garden, 2nd Street, Nungambakkam, ...
# 15          1.0     4.6  12/1, Opposite Royal Enfield Showroom, Greams ...
# 16          3.0     4.1  19, 3rd Street, Wallace Garden Road, Nungambak...
# 17          2.0     4.1  Families Complex, Medavakkam Tank Road, Kilpau...
# 18          1.0     4.3     255, Triplicane High Road, Triplicane, Chennai
# 19          1.0     3.4  338, Mint Street, Near Kakada Ramprasad, Sowca...
# 20          4.0     4.4  37, Taj Coromandel, Mahatma Gandhi Road, Nunga...
# 21          1.0     4.0  10, Khader Nawaz Khan Road, Opposite Evoluzion...
# 22          3.0     4.2  315, Harrisons Hotel, Valluvar Kottam High Roa...
# 23          2.0     3.9  307, Valluvar Kottam High Road, Nungambakkam, ...
# 24          1.0     4.1      58/2, Akbar Saheb Street, Triplicane, Chennai
# 25          3.0     4.0           71, Cathedral Road, Gopalapuram, Chennai
# 26          3.0     4.2          37, Kaveri Complex, Nungambakkam, Chennai
# 27          3.0     4.1           58-A, Habibullah Road, T. Nagar, Chennai
# 28          2.0     4.2  55, Ali Tower, Greams Road, Opposite IDBI Bank...
# 29          2.0     4.4  1, Poes Garden, Kasturi Estate, 1st Street, Al...
# 30          1.0     4.3  149, Fountain Plaza, Pantheon Road, Egmore, Ch...
# 31          2.0     4.2  119, D Block, 1st Main Road, Chintamani, Oppos...
# 32          1.0     4.3  No:140,Habibullah Road,Opp To Vidhyodaya Schoo...
# 33          2.0     3.8  58, Plot 120, C Block, 1st Main Road, Chintham...
# 34          2.0     4.2  7, 7th Cross Street, Near Thiru Vee Ka Park, A...
# 35          1.0     4.6  2/247, Perinbavilas Complex, Opposite Chitra A...
# 36          2.0     4.2                 12/5, Ormes Road, Kilpauk, Chennai
# 37          2.0     3.2           1, Vellala Street, Purasavakkam, Chennai
# 38          1.0     4.1  6, D Block, 6th Street, Behind Chinthamani, An...
# 39          1.0     3.2    Saravana Stores Building, Purasavakkam, Chennai
# 41          1.0     3.8           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 42          1.0     3.8           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 43          1.0     4.0   5, Purasavakkam High Road, Purasavakkam, Chennai
# 44          2.0     4.1  59, Block C, 1st Avenue, Anna Nagar East, Chennai
# 45          2.0     3.9  51, Gangadeshwar Koil Street, Purasavakkam, Ch...
# 46          2.0     3.3  226, Om Sakthi Plaza, Kilpauk Garden Road, Kil...
# 47          2.0     4.3  12 & 14, 1st Floor, Balfour Road, Windsor Pala...
# 48          1.0     3.3  73, G.E.C Tower, M.S Kovil Street, Royapuram, ...
# 49          2.0     3.8  58, Plot 120, C Block, 1st Main Road, Chintham...
# 50          1.0     3.8  37/15, Nelson Manickam Road, Choolaimedu, Chennai
#
#        Review
# 0        Good
# 1        Good
# 2        Good
# 3   Excellent
# 4   Excellent
# 5        Good
# 6         Bad
# 7        Good
# 8        Good
# 9        Good
# 10  Excellent
# 11  Excellent
# 12       Good
# 13  Excellent
# 14  Excellent
# 15  Excellent
# 16       Good
# 17       Good
# 18  Excellent
# 19       Good
# 20  Excellent
# 21       Good
# 22       Good
# 23       Good
# 24       Good
# 25       Good
# 26       Good
# 27       Good
# 28       Good
# 29  Excellent
# 30  Excellent
# 31       Good
# 32  Excellent
# 33       Good
# 34       Good
# 35  Excellent
# 36       Good
# 37    Average
# 38       Good
# 39    Average
# 41       Good
# 42       Good
# 43       Good
# 44       Good
# 45       Good
# 46       Good
# 47  Excellent
# 48       Good
# 49       Good
# 50       Good

# %% [markdown]
# Now we assign colors according to their rating bins. The corresponding colors are :
# * 0-2.5     (Bad) is **red**
# * 2.5-3.2   (Average) is **green**
# * 3.2-4.2 (Good) is **lightblue**
# * 4.2-5.0 (Excellent) is **darkblue**
#
# We assign the colors to the marker and plot the markers on the map with the help of the folium library.

# %%
color_map = {'Bad': 'red', 'Average': 'green', 'Good': 'lightblue', 'Excellent': 'darkblue '}

chennai_map_review = folium.Map(location = [chennai_latitude,chennai_longitude], zoom_start = 13)

for name, address, latitude, longitude, rating in zip(data['Venue Name'], 
                                                          data['Venue Address'], 
                                                          data['Latitude'], 
                                                          data['Longitude'], 
                                                          data['Review']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html = True)
    folium.Marker(
        [latitude, longitude],
        icon = folium.Icon(color = color_map[rating]),
        popup = label).add_to(chennai_map_review)  
chennai_map_review
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now lets **visualize the venue count against price for two** with the help of a **scatter plot**.

# %%
average_prices = data['Price'].value_counts().sort_index()
plt.figure(figsize = (15, 8))
plt.scatter(average_prices.index, 
            average_prices.values, 
            s = average_prices.index*10, 
            c = cm.hsv(np.linspace(0, 1, len(average_prices.index))))
plt.xlabel("Price For Two", fontsize = 17)
plt.ylabel("Venue Count", fontsize = 17)
# Out:
# Text(0, 0.5, 'Venue Count')

# %% [markdown]
# Now lets **map the venues based on their price**, Color Code :
# * Cheap is **darkblue**
# * Average is **lightblue**
# * Affordable is **green**
# * Expensive is **red**

# %%
bins = [0,500,1000,2000,6000]
labels = ['Cheap', 'Average', 'Affordable', 'Expensive']
data['Cost'] = pd.cut(data['Price'].astype(float), bins = bins, labels = labels, include_lowest = True)
color_map = {'Cheap': 'darkblue', 'Average': 'lightblue', 'Affordable': 'green', 'Expensive': 'red'}

chennai_map_prices = folium.Map(location = [chennai_latitude,chennai_longitude], zoom_start = 13)

for name, address, latitude, longitude, cost in zip(data['Venue Name'], 
                                                           data['Venue Address'], 
                                                           data['Latitude'], 
                                                           data['Longitude'], 
                                                           data['Cost']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html = True)
    folium.Marker(
        [latitude, longitude],
        icon = folium.Icon(color = color_map[cost]),
        popup = label).add_to(chennai_map_prices)  
chennai_map_prices
data
# Out:
#     Category                          Venue Name  Latitude  Longitude   Price  \
# 0          2                               Links   13.0799    80.2545   250.0
# 1          1          National Durbar Restaurant   13.0812    80.2708   500.0
# 2          1                  Mathura Restaurant   13.0663    80.2691   500.0
# 3          2                        Bombay Lassi   13.0659    80.2712   100.0
# 4          1                        Shree Mithai   13.0718    80.2480   350.0
# 5          2                      The Cake World   13.0604    80.2546   350.0
# 6          0                     Cafe Coffee Day   13.0586    80.2642   600.0
# 7          0                      Tibb's Frankie   13.0556    80.2578   200.0
# 8          0              Blend - Taj Club House   13.0613    80.2642  5000.0
# 9          0                      Tibb's Frankie   13.0556    80.2578   200.0
# 10         2  Amadora Gourmet Ice Cream & Sorbet   13.0609    80.2495   500.0
# 11         0                       Welcome Hotel   13.0856    80.2546   300.0
# 12         2                        Krispy Kreme   13.0589    80.2640   400.0
# 13         1                           Nair Mess   13.0644    80.2776   200.0
# 14         2        Sandy's Chocolate Laboratory   13.0609    80.2483  1400.0
# 15         1                        Kabab Corner   13.0599    80.2545   450.0
# 16         1                    Tuscana Pizzeria   13.0613    80.2499  1200.0
# 17         1            Al-Najeeb Nawab Of Kebab   13.0878    80.2435   500.0
# 18         1                          Ratna Cafe   13.0584    80.2742   400.0
# 19         1                 Anmol Mohit Patiala   13.0903    80.2791   100.0
# 20         0      Golden Dragon - Taj Coromandel   13.0585    80.2475  2800.0
# 21         2                       Cream & Fudge   13.0607    80.2515   350.0
# 22         1                             Dynasty   13.0666    80.2429  1200.0
# 23         1                  Hotel Raaj Bhaavan   13.0641    80.2435   600.0
# 24         1                   Kasivinayaga Mess   13.0608    80.2769   200.0
# 25         0   Sera - The Tapas Bar & Restaurant   13.0456    80.2580  1600.0
# 26         1                              Dahlia   13.0625    80.2452  1500.0
# 27         1                  Basil With A Twist   13.0497    80.2423  1500.0
# 28         1                   Savoury Sea Shell   13.0572    80.2552   750.0
# 29         1                        Ente Keralam   13.0422    80.2559   750.0
# 30         1                             Ajanabi   13.0677    80.2565   250.0
# 31         1                             Zaitoon   13.0835    80.2255   900.0
# 32         2                               ibaco   13.0500    80.2401   200.0
# 33         1           A2B - Adyar Ananda Bhavan   13.0842    80.2246   600.0
# 34         2                         Coffeetales   13.0818    80.2250   500.0
# 35         1    Momo Sa-Khang by Kailash Kitchen   13.0654    80.2310   350.0
# 36         1                     Hotel Paramount   13.0814    80.2477   500.0
# 37         1               Hotel Saravana Bhavan   13.0852    80.2522   550.0
# 38         1                         Al Kebabish   13.0854    80.2249   400.0
# 39         0                      Tibb's Frankie   13.0861    80.2568   200.0
# 41         1                   Murugan Idli Shop   13.0813    80.2480   200.0
# 42         1                   Murugan Idli Shop   13.0813    80.2480   200.0
# 43         1                        Doveton Cafe   13.0865    80.2581   400.0
# 44         1                        Buhari Hotel   13.0840    80.2245   850.0
# 45         1                          Rang Mahal   13.0818    80.2544   800.0
# 46         2                McCafe by McDonald's   13.0833    80.2403   500.0
# 47         1                  Bombay Halwa House   13.0852    80.2448   500.0
# 48         2                             Jil Jil   13.1082    80.2916   200.0
# 49         0           A2B - Adyar Ananda Bhavan   13.0842    80.2246   600.0
# 50         1               New Loyola Fast Foods   13.0666    80.2305   250.0
#
#     Price Range  Rating                                      Venue Address  \
# 0           1.0     4.1     22, Raja Annamalai Road, Purasavakkam, Chennai
# 1           2.0     4.1  3, Raja Muthiah Road, Near Central Railway Sta...
# 2           2.0     4.2  826, 2nd Floor, Tarapore Towers, Anna Salai, T...
# 3           1.0     4.4  8, Bahar Agan Street, Anna Salai, Ellis Road, ...
# 4           1.0     4.5                   18, Dr TV Road, Chetpet, Chennai
# 5           1.0     3.5  11/2, Greams Road, Near Police Station, Thousa...
# 6           2.0     2.4  49/15, 3rd Floor, Express Avenue Mall, Whites ...
# 7           1.0     3.8  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 8           4.0     4.1  Taj Club House Hotel, 2, Club House Road,  Ann...
# 9           1.0     3.8  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...
# 10          2.0     4.6  23, Wallace Garden, 3rd Street, Nungambakkam, ...
# 11          1.0     4.6  112/241, Purasawalkam High Road, Purasavakkam,...
# 12          1.0     4.2  Upper Ground Floor, Express Avenue, Whites Roa...
# 13          1.0     4.5  22, Mohammed Abdullah, 2nd Street, Opposite Ch...
# 14          3.0     4.3  16, Wallace Garden, 2nd Street, Nungambakkam, ...
# 15          1.0     4.6  12/1, Opposite Royal Enfield Showroom, Greams ...
# 16          3.0     4.1  19, 3rd Street, Wallace Garden Road, Nungambak...
# 17          2.0     4.1  Families Complex, Medavakkam Tank Road, Kilpau...
# 18          1.0     4.3     255, Triplicane High Road, Triplicane, Chennai
# 19          1.0     3.4  338, Mint Street, Near Kakada Ramprasad, Sowca...
# 20          4.0     4.4  37, Taj Coromandel, Mahatma Gandhi Road, Nunga...
# 21          1.0     4.0  10, Khader Nawaz Khan Road, Opposite Evoluzion...
# 22          3.0     4.2  315, Harrisons Hotel, Valluvar Kottam High Roa...
# 23          2.0     3.9  307, Valluvar Kottam High Road, Nungambakkam, ...
# 24          1.0     4.1      58/2, Akbar Saheb Street, Triplicane, Chennai
# 25          3.0     4.0           71, Cathedral Road, Gopalapuram, Chennai
# 26          3.0     4.2          37, Kaveri Complex, Nungambakkam, Chennai
# 27          3.0     4.1           58-A, Habibullah Road, T. Nagar, Chennai
# 28          2.0     4.2  55, Ali Tower, Greams Road, Opposite IDBI Bank...
# 29          2.0     4.4  1, Poes Garden, Kasturi Estate, 1st Street, Al...
# 30          1.0     4.3  149, Fountain Plaza, Pantheon Road, Egmore, Ch...
# 31          2.0     4.2  119, D Block, 1st Main Road, Chintamani, Oppos...
# 32          1.0     4.3  No:140,Habibullah Road,Opp To Vidhyodaya Schoo...
# 33          2.0     3.8  58, Plot 120, C Block, 1st Main Road, Chintham...
# 34          2.0     4.2  7, 7th Cross Street, Near Thiru Vee Ka Park, A...
# 35          1.0     4.6  2/247, Perinbavilas Complex, Opposite Chitra A...
# 36          2.0     4.2                 12/5, Ormes Road, Kilpauk, Chennai
# 37          2.0     3.2           1, Vellala Street, Purasavakkam, Chennai
# 38          1.0     4.1  6, D Block, 6th Street, Behind Chinthamani, An...
# 39          1.0     3.2    Saravana Stores Building, Purasavakkam, Chennai
# 41          1.0     3.8           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 42          1.0     3.8           31 & 12/3A, Ormes Road, Kilpauk, Chennai
# 43          1.0     4.0   5, Purasavakkam High Road, Purasavakkam, Chennai
# 44          2.0     4.1  59, Block C, 1st Avenue, Anna Nagar East, Chennai
# 45          2.0     3.9  51, Gangadeshwar Koil Street, Purasavakkam, Ch...
# 46          2.0     3.3  226, Om Sakthi Plaza, Kilpauk Garden Road, Kil...
# 47          2.0     4.3  12 & 14, 1st Floor, Balfour Road, Windsor Pala...
# 48          1.0     3.3  73, G.E.C Tower, M.S Kovil Street, Royapuram, ...
# 49          2.0     3.8  58, Plot 120, C Block, 1st Main Road, Chintham...
# 50          1.0     3.8  37/15, Nelson Manickam Road, Choolaimedu, Chennai
#
#        Review        Cost
# 0        Good       Cheap
# 1        Good       Cheap
# 2        Good       Cheap
# 3   Excellent       Cheap
# 4   Excellent       Cheap
# 5        Good       Cheap
# 6         Bad     Average
# 7        Good       Cheap
# 8        Good   Expensive
# 9        Good       Cheap
# 10  Excellent       Cheap
# 11  Excellent       Cheap
# 12       Good       Cheap
# 13  Excellent       Cheap
# 14  Excellent  Affordable
# 15  Excellent       Cheap
# 16       Good  Affordable
# 17       Good       Cheap
# 18  Excellent       Cheap
# 19       Good       Cheap
# 20  Excellent   Expensive
# 21       Good       Cheap
# 22       Good  Affordable
# 23       Good     Average
# 24       Good       Cheap
# 25       Good  Affordable
# 26       Good  Affordable
# 27       Good  Affordable
# 28       Good     Average
# 29  Excellent     Average
# 30  Excellent       Cheap
# 31       Good     Average
# 32  Excellent       Cheap
# 33       Good     Average
# 34       Good       Cheap
# 35  Excellent       Cheap
# 36       Good       Cheap
# 37    Average     Average
# 38       Good       Cheap
# 39    Average       Cheap
# 41       Good       Cheap
# 42       Good       Cheap
# 43       Good       Cheap
# 44       Good     Average
# 45       Good     Average
# 46       Good       Cheap
# 47  Excellent       Cheap
# 48       Good       Cheap
# 49       Good     Average
# 50       Good       Cheap

# %% [markdown]
# # Clustering

# %% [markdown]
# We will now be clustering the data with the help of **Affinity Propagation Clustering**.

# %%
from sklearn.cluster import AffinityPropagation

# %%
clustering_data = data[['Price','Rating','Category']]

# %% [markdown]
# We now fit the data to the AffinityPropagation Clustering model.

# %%
clustering = AffinityPropagation().fit(clustering_data)

# %%
data.insert(0, 'Affinity Cluster No.', clustering.labels_)
data['Affinity Cluster No.'].values
# Out:
# array([6, 5, 5, 6, 2, 2, 5, 6, 0, 6, 5, 2, 2, 6, 4, 2, 1, 5, 2, 6, 3, 2,
#        1, 5, 6, 4, 4, 4, 7, 7, 6, 7, 6, 5, 5, 2, 5, 5, 2, 6, 6, 6, 2, 7,
#        7, 5, 5, 6, 5, 6], dtype=int64)

# %% [markdown]
# Let us now map the clustered data based on their clusters on to the Chennai map with the help of the folium library.

# %%
chennai_clusters_map = folium.Map(location = [chennai_latitude,chennai_longitude], zoom_start = 13)
color_map = { 0: 'purple', 1: 'red', 2: 'black',3:'blue',4:'green',5:'orange',6:'grey',7:'white'}
markers_colors = []
for venue, address, cluster, latitude, longitude in zip(data['Venue Name'], 
                                                        data['Venue Address'], 
                                                        data['Affinity Cluster No.'], 
                                                        data['Latitude'], 
                                                        data['Longitude']):
    label = folium.Popup(str(venue) + ', ' + str(address), parse_html = True)
    folium.CircleMarker(
        [latitude, longitude],
        radius = 5,
        popup = label,
        color = color_map[cluster],
        fill = True,
        fill_color = color_map[cluster],
        fill_opacity = 0.7).add_to(chennai_clusters_map)

for index, cluster in enumerate(clustering.cluster_centers_):
    latitude = cluster[0]
    longitude = cluster[1]
    label = folium.Popup("Cluster: " + str(index), parse_html = True)
    folium.CircleMarker(
        [latitude, longitude],
        radius = 10,
        popup = label,
        color = color_map[index],
        fill = True,
        fill_color = color_map[index],
        fill_opacity = 1).add_to(chennai_clusters_map)
chennai_clusters_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Cluster - 0 (PURPLE)

# %%
result = data[data['Affinity Cluster No.'] == 0]
rows = result.shape[0]
print("Cluster 0 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 0 :
# Average Price for two : 5000.00
# Average Rating : 4.10
# No of Venues : 1
#    Affinity Cluster No.  Category              Venue Name  Latitude  \
# 0                     0         0  Blend - Taj Club House   13.0613
#
#    Longitude   Price  Price Range  Rating  \
# 0    80.2642  5000.0          4.0     4.1
#
#                                        Venue Address Review       Cost
# 0  Taj Club House Hotel, 2, Club House Road,  Ann...   Good  Expensive

# %% [markdown]
# ### Cluster - 1 (RED)

# %%
result = data[data['Affinity Cluster No.'] == 1]
rows = result.shape[0]
print("Cluster 1 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 1 :
# Average Price for two : 1200.00
# Average Rating : 4.15
# No of Venues : 2
#    Affinity Cluster No.  Category        Venue Name  Latitude  Longitude  \
# 0                     1         1  Tuscana Pizzeria   13.0613    80.2499
# 1                     1         1           Dynasty   13.0666    80.2429
#
#     Price  Price Range  Rating  \
# 0  1200.0          3.0     4.1
# 1  1200.0          3.0     4.2
#
#                                        Venue Address Review        Cost
# 0  19, 3rd Street, Wallace Garden Road, Nungambak...   Good  Affordable
# 1  315, Harrisons Hotel, Valluvar Kottam High Roa...   Good  Affordable

# %% [markdown]
# ### Cluster - 2 (BLACK)

# %%
result = data[data['Affinity Cluster No.'] == 2]
rows = result.shape[0]
print("Cluster 2 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 2 :
# Average Price for two : 375.00
# Average Rating : 4.24
# No of Venues : 10
#    Affinity Cluster No.  Category                        Venue Name  Latitude  \
# 0                     2         1                      Shree Mithai   13.0718
# 1                     2         2                    The Cake World   13.0604
# 2                     2         0                     Welcome Hotel   13.0856
# 3                     2         2                      Krispy Kreme   13.0589
# 4                     2         1                      Kabab Corner   13.0599
# 5                     2         1                        Ratna Cafe   13.0584
# 6                     2         2                     Cream & Fudge   13.0607
# 7                     2         1  Momo Sa-Khang by Kailash Kitchen   13.0654
# 8                     2         1                       Al Kebabish   13.0854
# 9                     2         1                      Doveton Cafe   13.0865
#
#    Longitude  Price  Price Range  Rating  \
# 0    80.2480  350.0          1.0     4.5
# 1    80.2546  350.0          1.0     3.5
# 2    80.2546  300.0          1.0     4.6
# 3    80.2640  400.0          1.0     4.2
# 4    80.2545  450.0          1.0     4.6
# 5    80.2742  400.0          1.0     4.3
# 6    80.2515  350.0          1.0     4.0
# 7    80.2310  350.0          1.0     4.6
# 8    80.2249  400.0          1.0     4.1
# 9    80.2581  400.0          1.0     4.0
#
#                                        Venue Address     Review   Cost
# 0                   18, Dr TV Road, Chetpet, Chennai  Excellent  Cheap
# 1  11/2, Greams Road, Near Police Station, Thousa...       Good  Cheap
# 2  112/241, Purasawalkam High Road, Purasavakkam,...  Excellent  Cheap
# 3  Upper Ground Floor, Express Avenue, Whites Roa...       Good  Cheap
# 4  12/1, Opposite Royal Enfield Showroom, Greams ...  Excellent  Cheap
# 5     255, Triplicane High Road, Triplicane, Chennai  Excellent  Cheap
# 6  10, Khader Nawaz Khan Road, Opposite Evoluzion...       Good  Cheap
# 7  2/247, Perinbavilas Complex, Opposite Chitra A...  Excellent  Cheap
# 8  6, D Block, 6th Street, Behind Chinthamani, An...       Good  Cheap
# 9   5, Purasavakkam High Road, Purasavakkam, Chennai       Good  Cheap

# %% [markdown]
# ### Cluster - 3 (BLUE)

# %%
result = data[data['Affinity Cluster No.'] == 3]
rows = result.shape[0]
print("Cluster 3 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 3 :
# Average Price for two : 2800.00
# Average Rating : 4.40
# No of Venues : 1
#    Affinity Cluster No.  Category                      Venue Name  Latitude  \
# 0                     3         0  Golden Dragon - Taj Coromandel   13.0585
#
#    Longitude   Price  Price Range  Rating  \
# 0    80.2475  2800.0          4.0     4.4
#
#                                        Venue Address     Review       Cost
# 0  37, Taj Coromandel, Mahatma Gandhi Road, Nunga...  Excellent  Expensive

# %% [markdown]
# ### Cluster - 4 (GREEN)

# %%
result = data[data['Affinity Cluster No.'] == 4]
rows = result.shape[0]
print("Cluster 4 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 4 :
# Average Price for two : 1500.00
# Average Rating : 4.15
# No of Venues : 4
#    Affinity Cluster No.  Category                         Venue Name  \
# 0                     4         2       Sandy's Chocolate Laboratory
# 1                     4         0  Sera - The Tapas Bar & Restaurant
# 2                     4         1                             Dahlia
# 3                     4         1                 Basil With A Twist
#
#    Latitude  Longitude   Price  Price Range  Rating  \
# 0   13.0609    80.2483  1400.0          3.0     4.3
# 1   13.0456    80.2580  1600.0          3.0     4.0
# 2   13.0625    80.2452  1500.0          3.0     4.2
# 3   13.0497    80.2423  1500.0          3.0     4.1
#
#                                        Venue Address     Review        Cost
# 0  16, Wallace Garden, 2nd Street, Nungambakkam, ...  Excellent  Affordable
# 1           71, Cathedral Road, Gopalapuram, Chennai       Good  Affordable
# 2          37, Kaveri Complex, Nungambakkam, Chennai       Good  Affordable
# 3           58-A, Habibullah Road, T. Nagar, Chennai       Good  Affordable

# %% [markdown]
# ### Cluster - 5 (ORANGE)

# %%
result = data[data['Affinity Cluster No.'] == 5]
rows = result.shape[0]
print("Cluster 5 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 5 :
# Average Price for two : 534.62
# Average Rating : 3.85
# No of Venues : 13
#    Affinity Cluster No.  Category                          Venue Name  \
# 0                     5         1          National Durbar Restaurant
# 1                     5         1                  Mathura Restaurant
# 2                     5         0                     Cafe Coffee Day
# 3                     5         2  Amadora Gourmet Ice Cream & Sorbet
# 4                     5         1            Al-Najeeb Nawab Of Kebab
# 5                     5         1                  Hotel Raaj Bhaavan
# 6                     5         1           A2B - Adyar Ananda Bhavan
# 7                     5         2                         Coffeetales
# 8                     5         1                     Hotel Paramount
# 9                     5         1               Hotel Saravana Bhavan
#
#    Latitude  Longitude  Price  Price Range  Rating  \
# 0   13.0812    80.2708  500.0          2.0     4.1
# 1   13.0663    80.2691  500.0          2.0     4.2
# 2   13.0586    80.2642  600.0          2.0     2.4
# 3   13.0609    80.2495  500.0          2.0     4.6
# 4   13.0878    80.2435  500.0          2.0     4.1
# 5   13.0641    80.2435  600.0          2.0     3.9
# 6   13.0842    80.2246  600.0          2.0     3.8
# 7   13.0818    80.2250  500.0          2.0     4.2
# 8   13.0814    80.2477  500.0          2.0     4.2
# 9   13.0852    80.2522  550.0          2.0     3.2
#
#                                        Venue Address     Review     Cost
# 0  3, Raja Muthiah Road, Near Central Railway Sta...       Good    Cheap
# 1  826, 2nd Floor, Tarapore Towers, Anna Salai, T...       Good    Cheap
# 2  49/15, 3rd Floor, Express Avenue Mall, Whites ...        Bad  Average
# 3  23, Wallace Garden, 3rd Street, Nungambakkam, ...  Excellent    Cheap
# 4  Families Complex, Medavakkam Tank Road, Kilpau...       Good    Cheap
# 5  307, Valluvar Kottam High Road, Nungambakkam, ...       Good  Average
# 6  58, Plot 120, C Block, 1st Main Road, Chintham...       Good  Average
# 7  7, 7th Cross Street, Near Thiru Vee Ka Park, A...       Good    Cheap
# 8                 12/5, Ormes Road, Kilpauk, Chennai       Good    Cheap
# 9           1, Vellala Street, Purasavakkam, Chennai    Average  Average

# %% [markdown]
# ### Cluster - 6 (GREY)

# %%
result = data[data['Affinity Cluster No.'] == 6]
rows = result.shape[0]
print("Cluster 6 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 6 :
# Average Price for two : 196.43
# Average Rating : 3.90
# No of Venues : 14
#    Affinity Cluster No.  Category           Venue Name  Latitude  Longitude  \
# 0                     6         2                Links   13.0799    80.2545
# 1                     6         2         Bombay Lassi   13.0659    80.2712
# 2                     6         0       Tibb's Frankie   13.0556    80.2578
# 3                     6         0       Tibb's Frankie   13.0556    80.2578
# 4                     6         1            Nair Mess   13.0644    80.2776
# 5                     6         1  Anmol Mohit Patiala   13.0903    80.2791
# 6                     6         1    Kasivinayaga Mess   13.0608    80.2769
# 7                     6         1              Ajanabi   13.0677    80.2565
# 8                     6         2                ibaco   13.0500    80.2401
# 9                     6         0       Tibb's Frankie   13.0861    80.2568
#
#    Price  Price Range  Rating  \
# 0  250.0          1.0     4.1
# 1  100.0          1.0     4.4
# 2  200.0          1.0     3.8
# 3  200.0          1.0     3.8
# 4  200.0          1.0     4.5
# 5  100.0          1.0     3.4
# 6  200.0          1.0     4.1
# 7  250.0          1.0     4.3
# 8  200.0          1.0     4.3
# 9  200.0          1.0     3.2
#
#                                        Venue Address     Review   Cost
# 0     22, Raja Annamalai Road, Purasavakkam, Chennai       Good  Cheap
# 1  8, Bahar Agan Street, Anna Salai, Ellis Road, ...  Excellent  Cheap
# 2  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...       Good  Cheap
# 3  16, Thiru Vi Ka Road, Near Sathyam Theatre, Ro...       Good  Cheap
# 4  22, Mohammed Abdullah, 2nd Street, Opposite Ch...  Excellent  Cheap
# 5  338, Mint Street, Near Kakada Ramprasad, Sowca...       Good  Cheap
# 6      58/2, Akbar Saheb Street, Triplicane, Chennai       Good  Cheap
# 7  149, Fountain Plaza, Pantheon Road, Egmore, Ch...  Excellent  Cheap
# 8  No:140,Habibullah Road,Opp To Vidhyodaya Schoo...  Excellent  Cheap
# 9    Saravana Stores Building, Purasavakkam, Chennai    Average  Cheap

# %% [markdown]
# ### Cluster - 7 (WHITE)

# %%
result = data[data['Affinity Cluster No.'] == 7]
rows = result.shape[0]
print("Cluster 7 :\nAverage Price for two : {:.02f}\nAverage Rating : {:.02f}\nNo of Venues : {}".
      format(result['Price'].mean(), result['Rating'].astype(float).mean(),rows))
result.head(10).reset_index(drop = True)
# Out:
# Cluster 7 :
# Average Price for two : 810.00
# Average Rating : 4.16
# No of Venues : 5
#    Affinity Cluster No.  Category         Venue Name  Latitude  Longitude  \
# 0                     7         1  Savoury Sea Shell   13.0572    80.2552
# 1                     7         1       Ente Keralam   13.0422    80.2559
# 2                     7         1            Zaitoon   13.0835    80.2255
# 3                     7         1       Buhari Hotel   13.0840    80.2245
# 4                     7         1         Rang Mahal   13.0818    80.2544
#
#    Price  Price Range  Rating  \
# 0  750.0          2.0     4.2
# 1  750.0          2.0     4.4
# 2  900.0          2.0     4.2
# 3  850.0          2.0     4.1
# 4  800.0          2.0     3.9
#
#                                        Venue Address     Review     Cost
# 0  55, Ali Tower, Greams Road, Opposite IDBI Bank...       Good  Average
# 1  1, Poes Garden, Kasturi Estate, 1st Street, Al...  Excellent  Average
# 2  119, D Block, 1st Main Road, Chintamani, Oppos...       Good  Average
# 3  59, Block C, 1st Avenue, Anna Nagar East, Chennai       Good  Average
# 4  51, Gangadeshwar Koil Street, Purasavakkam, Ch...       Good  Average

# %% [markdown]
# # Results & Discussion

# %% [markdown]
# Our analysis provides an insight on the venues within a 5km radius of Chennai. We had found that **most venues were located in and around Nungambakkam & Thousand Lights**. The **most common venue category was Indian restaurants, tourists can enjoy the indian cuisine & Chennai's culture**. The city of **chennai mostly consists of venues rated between 3.5 & 4.5**, this is evidence that the **venues are well taken care of and satisfy their customers**. **Most venues had their prices between 500 Rupees & 1500 Rupees**, this is also evidence that the city of **Chennai is an affordable place where you can have a great time at decent prices**.

# %% [markdown]
# # Conclusion

# %% [markdown]
# **The whole purpose of this analysis is to provide information to the tourists visiting Chennai to make decisions based on their preferences** and also **promote tourism in Chennai**. We initially **acquired data from FoursquareAPI & ZomatoAPI**. we **cleaned the data** by combining the two datasets & removing venues with similar latitude & longitude co-ordinates. We **dropped venues which were not given ratings** yet. We the **visualized the data in the form of bar plots, scatter plots & maps** to come the conclusions mentioned in the results section. We then **grouped the data into clusters with the help of Affinity Propagation Clustering**. The description for each cluster is also mentioned above in the results section. In the end this information will only act as a guide or insight to the tourist. **The tourist is the one who will make the final decision on where they want to visit based on the rating, pricing, location etc.**
